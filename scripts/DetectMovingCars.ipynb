# %% [markdown]
# ### Path to folders

# %%
import os
from collections import Counter

# Define folder paths
image_folder_path = r"C:\Users\felix\Documents\MT_Data\Zone1_intersection"
detect_folder_path = r"C:\Users\felix\Documents\MT_Data\Yolo\Z1_intersection"

def get_image_files(path):
    """Returns a set of image filenames (without extensions)."""
    return {os.path.splitext(f)[0] for f in os.listdir(path) if f.lower().endswith('.jpg')}

def get_detection_files(path):
    """Returns a set of detection filenames (base name only, no extension)."""
    files = [f.replace("_detections.csv", "") for f in os.listdir(path) if f.lower().endswith('_detections.csv')]
    return set(files), Counter(files)  # Return set + count dictionary

# Get files
image_files = get_image_files(image_folder_path)
detect_files, detect_count = get_detection_files(detect_folder_path)

# Print counts
print(f" Number of images: {len(image_files)}")
print(f" Number of detection files: {len(detect_files)}")
# Out:
#  Number of images: 117
#  Number of detection files: 117

# %% [markdown]
# ### Read Exifdata from UAV-Images

# %%
import os
import math
import re
import subprocess

#image_folder_path = r"C:\Users\felix\Documents\GitHub\CarDetection\testzone\z1_turn\raw_images"

# Path to the ExifTool executable
exifToolPath = "../exiftool.exe"  # Adjust if necessary

# Initialize the dictionary to store metadata
image_metadata = {}

# Filter for image files in the folder (common extensions)
valid_extensions = {'.jpg', '.jpeg', '.png'}
image_files = [f for f in os.listdir(image_folder_path) if os.path.splitext(f)[-1].lower() in valid_extensions]

# Process each image in the folder
for filename in image_files:
    image_path = os.path.join(image_folder_path, filename)
    
    # Initialize subprocess to call ExifTool
    process = subprocess.Popen([exifToolPath, image_path], stdout=subprocess.PIPE, stderr=subprocess.STDOUT, universal_newlines=True)

    # Read and parse metadata
    infoDict = {}
    for tag in process.stdout:
        line = tag.strip().split(':')  # Split each line at the ':'
        if len(line) > 1:  # Ensure valid key-value pair
            infoDict[line[0].strip()] = line[-1].strip()

    # Extract required metadata
    try:
        relAlt = float(infoDict.get("Relative Altitude", 0))  # Default to 0 if not found
        #print(relAlt)
        absAlt = float(infoDict.get("Absolute Altitude", 0))
        gpslat = infoDict.get("GPS Latitude", "")
        gpslon = infoDict.get("GPS Longitude", "")
        iw = float(infoDict.get("Image Width", 0))
        #print(iw)
        fov = infoDict.get("Field Of View", "0")
        #print(fov)
        gimbal_roll_deg = float(infoDict.get("Gimbal Roll Degree", 0))
        gimbal_yaw_deg = float(infoDict.get("Gimbal Yaw Degree", 0))
        gimbal_pitch_deg = float(infoDict.get("Gimbal Pitch Degree", 0))
        flight_yaw_deg = float(infoDict.get("Flight Yaw Degree", 0))

        
        # Parse latitude
        if gpslat:
            lat_ori = gpslat[-1]
            matches = re.findall(r'(\d+(\.\d+)?)', gpslat)
            gpslat = [float(match[0]) for match in matches]
            lat_deg, lat_min, lat_sec = gpslat
            lat_dec = abs(lat_deg) + lat_min / 60 + lat_sec / 3600
            if lat_ori == 'S':
                lat_dec = -lat_dec
        else:
            lat_dec = None

        # Parse longitude
        if gpslon:
            lon_ori = gpslon[-1]
            matches = re.findall(r'(\d+(\.\d+)?)', gpslon)
            gpslon = [float(match[0]) for match in matches]
            lon_deg, lon_min, lon_sec = gpslon
            lon_dec = abs(lon_deg) + lon_min / 60 + lon_sec / 3600
            if lon_ori == 'W':
                lon_dec = -lon_dec
        else:
            lon_dec = None

        # Calculate GSD
        if iw > 0 and relAlt < 88:
            fov_value = float(re.findall(r'\d+\.\d+', fov)[0]) if fov else 0
            fovrad = math.radians(fov_value / 2)
            gsd = (math.tan(fovrad) * relAlt) / (iw / 2)
        else:
            gsd = 0.022 # Default value

        # Store the data in a dictionary
        image_metadata[filename] = {
            'Latitude': lat_dec,
            'Longitude': lon_dec,
            'Relative Altitude': relAlt,
            'Absolute Altitude': absAlt,
            'GSD': gsd,
            "Gimbal Roll Degree": gimbal_roll_deg,
            "Gimbal Yaw Degree": gimbal_yaw_deg,
            "Gimbal Pitch Degree": gimbal_pitch_deg,
            "Flight Yaw Degree": flight_yaw_deg
        }
    except Exception as e:
        print(f"Error processing file {filename}: {e}")

# Output the collected metadata
for image_name, metadata in image_metadata.items():
    print(f"Image: {image_name}")
    for key, value in metadata.items():
        print(f"  {key}: {value}")
    print()
# Out:
# Image: DJI_0613.JPG
#   Latitude: 5.682941666666667
#   Longitude: -0.03711388888888889
#   Relative Altitude: 89.9
#   Absolute Altitude: 115.4
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: 162.5
#
# Image: DJI_0614.JPG
#   Latitude: 5.682813888888889
#   Longitude: -0.037075
#   Relative Altitude: 90.0
#   Absolute Altitude: 115.38
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: 162.3
#
# Image: DJI_0615.JPG
#   Latitude: 5.682686111111112
#   Longitude: -0.03703611111111111
#   Relative Altitude: 90.0
#   Absolute Altitude: 115.33
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: 162.6
#
# Image: DJI_0616.JPG
#   Latitude: 5.682555555555556
#   Longitude: -0.03699722222222222
#   Relative Altitude: 89.9
#   Absolute Altitude: 115.29
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: 162.5
#
# Image: DJI_0617.JPG
#   Latitude: 5.682433333333334
#   Longitude: -0.03696111111111111
#   Relative Altitude: 90.0
#   Absolute Altitude: 115.42
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: 162.5
#
# Image: DJI_0618.JPG
#   Latitude: 5.682305555555556
#   Longitude: -0.036922222222222224
#   Relative Altitude: 90.0
#   Absolute Altitude: 115.41
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: 162.1
#
# Image: DJI_0619.JPG
#   Latitude: 5.682175
#   Longitude: -0.03688333333333333
#   Relative Altitude: 90.0
#   Absolute Altitude: 115.47
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: 162.6
#
# Image: DJI_0620.JPG
#   Latitude: 5.682044444444445
#   Longitude: -0.036844444444444444
#   Relative Altitude: 90.0
#   Absolute Altitude: 115.43
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: 162.5
#
# Image: DJI_0621.JPG
#   Latitude: 5.681916666666667
#   Longitude: -0.03680555555555556
#   Relative Altitude: 90.1
#   Absolute Altitude: 115.43
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: 162.8
#
# Image: DJI_0622.JPG
#   Latitude: 5.681788888888889
#   Longitude: -0.03676666666666667
#   Relative Altitude: 90.0
#   Absolute Altitude: 115.2
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: 162.3
#
# Image: DJI_0623.JPG
#   Latitude: 5.6816611111111115
#   Longitude: -0.036727777777777776
#   Relative Altitude: 90.0
#   Absolute Altitude: 115.03
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: 162.6
#
# Image: DJI_0624.JPG
#   Latitude: 5.681530555555556
#   Longitude: -0.03668888888888889
#   Relative Altitude: 89.9
#   Absolute Altitude: 114.99
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: 162.6
#
# Image: DJI_0625.JPG
#   Latitude: 5.681419444444445
#   Longitude: -0.03665555555555555
#   Relative Altitude: 89.9
#   Absolute Altitude: 115.14
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: 164.8
#
# Image: DJI_0626.JPG
#   Latitude: 5.681380555555556
#   Longitude: -0.03690277777777778
#   Relative Altitude: 90.2
#   Absolute Altitude: 114.97
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -7.4
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: -16.9
#
# Image: DJI_0627.JPG
#   Latitude: 5.681497222222222
#   Longitude: -0.03693888888888889
#   Relative Altitude: 90.4
#   Absolute Altitude: 114.58
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -7.0
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: -16.9
#
# Image: DJI_0628.JPG
#   Latitude: 5.681622222222223
#   Longitude: -0.036977777777777776
#   Relative Altitude: 90.2
#   Absolute Altitude: 114.03
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.8
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: -16.8
#
# Image: DJI_0629.JPG
#   Latitude: 5.681752777777778
#   Longitude: -0.03701666666666666
#   Relative Altitude: 90.2
#   Absolute Altitude: 113.77
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.7
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: -16.7
#
# Image: DJI_0630.JPG
#   Latitude: 5.681880555555556
#   Longitude: -0.03705555555555556
#   Relative Altitude: 90.0
#   Absolute Altitude: 113.59
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.7
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: -17.0
#
# Image: DJI_0631.JPG
#   Latitude: 5.6820055555555555
#   Longitude: -0.037094444444444444
#   Relative Altitude: 90.1
#   Absolute Altitude: 113.43
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.6
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: -16.9
#
# Image: DJI_0632.JPG
#   Latitude: 5.682141666666667
#   Longitude: -0.03713333333333333
#   Relative Altitude: 90.1
#   Absolute Altitude: 113.26
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.6
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: -16.9
#
# Image: DJI_0633.JPG
#   Latitude: 5.6822638888888894
#   Longitude: -0.037172222222222225
#   Relative Altitude: 90.0
#   Absolute Altitude: 113.1
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.6
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: -16.6
#
# Image: DJI_0634.JPG
#   Latitude: 5.682397222222223
#   Longitude: -0.03721111111111111
#   Relative Altitude: 90.0
#   Absolute Altitude: 113.22
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.6
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: -17.1
#
# Image: DJI_0635.JPG
#   Latitude: 5.682519444444445
#   Longitude: -0.03724722222222222
#   Relative Altitude: 90.0
#   Absolute Altitude: 113.45
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.6
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: -16.7
#
# Image: DJI_0636.JPG
#   Latitude: 5.682650000000001
#   Longitude: -0.03728611111111111
#   Relative Altitude: 90.1
#   Absolute Altitude: 113.58
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.6
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: -16.7
#
# Image: DJI_0637.JPG
#   Latitude: 5.682777777777778
#   Longitude: -0.037325
#   Relative Altitude: 90.0
#   Absolute Altitude: 113.77
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.6
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: -17.1
#
# Image: DJI_0638.JPG
#   Latitude: 5.682905555555556
#   Longitude: -0.03736388888888889
#   Relative Altitude: 90.1
#   Absolute Altitude: 113.86
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.6
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: -17.0
#
# Image: DJI_0639.JPG
#   Latitude: 5.683036111111112
#   Longitude: -0.03740277777777778
#   Relative Altitude: 90.0
#   Absolute Altitude: 113.84
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.6
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: -17.1
#
# Image: DJI_0640.JPG
#   Latitude: 5.683163888888889
#   Longitude: -0.037441666666666665
#   Relative Altitude: 90.0
#   Absolute Altitude: 113.97
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.6
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: -16.9
#
# Image: DJI_0641.JPG
#   Latitude: 5.683288888888889
#   Longitude: -0.03748055555555556
#   Relative Altitude: 90.1
#   Absolute Altitude: 113.91
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: -16.8
#
# Image: DJI_0642.JPG
#   Latitude: 5.683416666666667
#   Longitude: -0.037519444444444446
#   Relative Altitude: 89.9
#   Absolute Altitude: 113.85
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: -16.7
#
# Image: DJI_0643.JPG
#   Latitude: 5.68355
#   Longitude: -0.03755833333333333
#   Relative Altitude: 90.0
#   Absolute Altitude: 113.91
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: -16.9
#
# Image: DJI_0644.JPG
#   Latitude: 5.683675
#   Longitude: -0.03759722222222222
#   Relative Altitude: 90.0
#   Absolute Altitude: 113.73
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: -16.8
#
# Image: DJI_0645.JPG
#   Latitude: 5.683805555555556
#   Longitude: -0.03763611111111111
#   Relative Altitude: 90.0
#   Absolute Altitude: 113.64
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: -17.0
#
# Image: DJI_0646.JPG
#   Latitude: 5.683933333333334
#   Longitude: -0.037675
#   Relative Altitude: 90.0
#   Absolute Altitude: 113.6
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: -16.9
#
# Image: DJI_0647.JPG
#   Latitude: 5.684061111111111
#   Longitude: -0.03771388888888889
#   Relative Altitude: 89.9
#   Absolute Altitude: 113.5
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: -16.9
#
# Image: DJI_0648.JPG
#   Latitude: 5.684188888888889
#   Longitude: -0.037752777777777774
#   Relative Altitude: 90.0
#   Absolute Altitude: 113.55
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: -16.7
#
# Image: DJI_0649.JPG
#   Latitude: 5.684313888888889
#   Longitude: -0.037788888888888886
#   Relative Altitude: 90.0
#   Absolute Altitude: 113.6
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: -17.1
#
# Image: DJI_0650.JPG
#   Latitude: 5.68445
#   Longitude: -0.037830555555555555
#   Relative Altitude: 89.9
#   Absolute Altitude: 113.56
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: -16.9
#
# Image: DJI_0651.JPG
#   Latitude: 5.684577777777778
#   Longitude: -0.03786944444444444
#   Relative Altitude: 90.0
#   Absolute Altitude: 113.7
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: -16.8
#
# Image: DJI_0652.JPG
#   Latitude: 5.6847
#   Longitude: -0.03790555555555555
#   Relative Altitude: 90.0
#   Absolute Altitude: 113.71
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: -17.0
#
# Image: DJI_0653.JPG
#   Latitude: 5.684830555555556
#   Longitude: -0.03794444444444445
#   Relative Altitude: 90.0
#   Absolute Altitude: 113.71
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: -16.9
#
# Image: DJI_0654.JPG
#   Latitude: 5.684958333333333
#   Longitude: -0.037983333333333334
#   Relative Altitude: 90.0
#   Absolute Altitude: 113.82
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: -16.9
#
# Image: DJI_0655.JPG
#   Latitude: 5.685083333333334
#   Longitude: -0.03802222222222222
#   Relative Altitude: 90.0
#   Absolute Altitude: 113.92
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: -16.6
#
# Image: DJI_0656.JPG
#   Latitude: 5.685216666666667
#   Longitude: -0.03806111111111111
#   Relative Altitude: 89.9
#   Absolute Altitude: 113.79
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: -16.9
#
# Image: DJI_0657.JPG
#   Latitude: 5.685338888888889
#   Longitude: -0.0381
#   Relative Altitude: 90.0
#   Absolute Altitude: 113.86
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: -16.9
#
# Image: DJI_0658.JPG
#   Latitude: 5.685475
#   Longitude: -0.03813888888888889
#   Relative Altitude: 90.0
#   Absolute Altitude: 113.86
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: -16.8
#
# Image: DJI_0659.JPG
#   Latitude: 5.685597222222222
#   Longitude: -0.038177777777777776
#   Relative Altitude: 89.9
#   Absolute Altitude: 113.7
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: -16.7
#
# Image: DJI_0660.JPG
#   Latitude: 5.685727777777778
#   Longitude: -0.03821666666666666
#   Relative Altitude: 90.0
#   Absolute Altitude: 113.6
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: -16.7
#
# Image: DJI_0661.JPG
#   Latitude: 5.685855555555555
#   Longitude: -0.03825555555555556
#   Relative Altitude: 90.0
#   Absolute Altitude: 113.54
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: -16.8
#
# Image: DJI_0662.JPG
#   Latitude: 5.685986111111111
#   Longitude: -0.03829444444444444
#   Relative Altitude: 90.0
#   Absolute Altitude: 113.57
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: -16.8
#
# Image: DJI_0663.JPG
#   Latitude: 5.686113888888889
#   Longitude: -0.03833333333333333
#   Relative Altitude: 90.0
#   Absolute Altitude: 113.53
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: -16.9
#
# Image: DJI_0664.JPG
#   Latitude: 5.686238888888889
#   Longitude: -0.03836944444444444
#   Relative Altitude: 90.0
#   Absolute Altitude: 113.63
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: -17.0
#
# Image: DJI_0665.JPG
#   Latitude: 5.686372222222222
#   Longitude: -0.03841111111111111
#   Relative Altitude: 90.0
#   Absolute Altitude: 113.67
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: -17.0
#
# Image: DJI_0666.JPG
#   Latitude: 5.6864944444444445
#   Longitude: -0.03844722222222222
#   Relative Altitude: 89.9
#   Absolute Altitude: 113.76
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: -16.8
#
# Image: DJI_0667.JPG
#   Latitude: 5.686625
#   Longitude: -0.03848611111111111
#   Relative Altitude: 90.1
#   Absolute Altitude: 113.82
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: -16.9
#
# Image: DJI_0668.JPG
#   Latitude: 5.686747222222222
#   Longitude: -0.038525000000000004
#   Relative Altitude: 90.0
#   Absolute Altitude: 113.69
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: -16.8
#
# Image: DJI_0669.JPG
#   Latitude: 5.686880555555556
#   Longitude: -0.03856388888888889
#   Relative Altitude: 90.0
#   Absolute Altitude: 113.72
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: -18.2
#
# Image: DJI_0670.JPG
#   Latitude: 5.686911111111112
#   Longitude: -0.0386
#   Relative Altitude: 89.7
#   Absolute Altitude: 113.73
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: -34.9
#
# Image: DJI_0671.JPG
#   Latitude: 5.686761111111111
#   Longitude: -0.03878888888888889
#   Relative Altitude: 90.0
#   Absolute Altitude: 114.79
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 174.3
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: 161.6
#
# Image: DJI_0672.JPG
#   Latitude: 5.686641666666667
#   Longitude: -0.03875555555555556
#   Relative Altitude: 89.8
#   Absolute Altitude: 114.72
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.9
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: 162.7
#
# Image: DJI_0673.JPG
#   Latitude: 5.686511111111112
#   Longitude: -0.03871666666666666
#   Relative Altitude: 89.8
#   Absolute Altitude: 114.84
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.7
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: 162.9
#
# Image: DJI_0674.JPG
#   Latitude: 5.686383333333334
#   Longitude: -0.038677777777777776
#   Relative Altitude: 89.9
#   Absolute Altitude: 115.01
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.6
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: 162.5
#
# Image: DJI_0675.JPG
#   Latitude: 5.686252777777778
#   Longitude: -0.03863888888888889
#   Relative Altitude: 90.0
#   Absolute Altitude: 114.71
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.6
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: 162.6
#
# Image: DJI_0676.JPG
#   Latitude: 5.6861250000000005
#   Longitude: -0.0386
#   Relative Altitude: 89.8
#   Absolute Altitude: 114.43
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.6
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: 162.7
#
# Image: DJI_0677.JPG
#   Latitude: 5.686
#   Longitude: -0.03856111111111111
#   Relative Altitude: 89.8
#   Absolute Altitude: 114.43
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: 162.7
#
# Image: DJI_0678.JPG
#   Latitude: 5.685866666666667
#   Longitude: -0.03852222222222222
#   Relative Altitude: 89.8
#   Absolute Altitude: 114.37
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: 162.7
#
# Image: DJI_0679.JPG
#   Latitude: 5.6857444444444445
#   Longitude: -0.038483333333333335
#   Relative Altitude: 89.8
#   Absolute Altitude: 114.27
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: 162.6
#
# Image: DJI_0680.JPG
#   Latitude: 5.685613888888889
#   Longitude: -0.03844444444444444
#   Relative Altitude: 89.8
#   Absolute Altitude: 114.3
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: 162.6
#
# Image: DJI_0681.JPG
#   Latitude: 5.6854861111111115
#   Longitude: -0.038405555555555554
#   Relative Altitude: 89.9
#   Absolute Altitude: 114.34
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: 162.6
#
# Image: DJI_0682.JPG
#   Latitude: 5.685358333333333
#   Longitude: -0.03836666666666667
#   Relative Altitude: 89.8
#   Absolute Altitude: 114.36
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: 162.6
#
# Image: DJI_0683.JPG
#   Latitude: 5.685227777777778
#   Longitude: -0.03832777777777778
#   Relative Altitude: 89.9
#   Absolute Altitude: 114.51
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: 162.6
#
# Image: DJI_0684.JPG
#   Latitude: 5.685105555555555
#   Longitude: -0.03829166666666667
#   Relative Altitude: 89.9
#   Absolute Altitude: 114.43
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: 162.7
#
# Image: DJI_0685.JPG
#   Latitude: 5.6849750000000006
#   Longitude: -0.038252777777777774
#   Relative Altitude: 89.8
#   Absolute Altitude: 114.54
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: 162.8
#
# Image: DJI_0686.JPG
#   Latitude: 5.684847222222222
#   Longitude: -0.03821388888888889
#   Relative Altitude: 90.0
#   Absolute Altitude: 114.64
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: 162.4
#
# Image: DJI_0687.JPG
#   Latitude: 5.684719444444445
#   Longitude: -0.038175
#   Relative Altitude: 89.9
#   Absolute Altitude: 114.54
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: 162.5
#
# Image: DJI_0688.JPG
#   Latitude: 5.684588888888889
#   Longitude: -0.03813611111111111
#   Relative Altitude: 89.9
#   Absolute Altitude: 114.51
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: 162.5
#
# Image: DJI_0689.JPG
#   Latitude: 5.684461111111111
#   Longitude: -0.03809722222222222
#   Relative Altitude: 89.9
#   Absolute Altitude: 114.45
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: 162.6
#
# Image: DJI_0690.JPG
#   Latitude: 5.684333333333334
#   Longitude: -0.03805833333333333
#   Relative Altitude: 89.9
#   Absolute Altitude: 114.41
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: 162.5
#
# Image: DJI_0691.JPG
#   Latitude: 5.684202777777778
#   Longitude: -0.038019444444444446
#   Relative Altitude: 89.9
#   Absolute Altitude: 114.43
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: 162.5
#
# Image: DJI_0692.JPG
#   Latitude: 5.684075
#   Longitude: -0.03798055555555556
#   Relative Altitude: 89.9
#   Absolute Altitude: 114.45
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: 162.6
#
# Image: DJI_0693.JPG
#   Latitude: 5.683952777777778
#   Longitude: -0.037941666666666665
#   Relative Altitude: 89.9
#   Absolute Altitude: 114.43
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: 162.4
#
# Image: DJI_0694.JPG
#   Latitude: 5.6838194444444445
#   Longitude: -0.03790277777777778
#   Relative Altitude: 89.9
#   Absolute Altitude: 114.47
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: 162.5
#
# Image: DJI_0695.JPG
#   Latitude: 5.683694444444445
#   Longitude: -0.037866666666666667
#   Relative Altitude: 89.9
#   Absolute Altitude: 114.6
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: 162.4
#
# Image: DJI_0696.JPG
#   Latitude: 5.683563888888889
#   Longitude: -0.037825
#   Relative Altitude: 89.9
#   Absolute Altitude: 114.74
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: 162.4
#
# Image: DJI_0697.JPG
#   Latitude: 5.683436111111111
#   Longitude: -0.03778611111111111
#   Relative Altitude: 89.9
#   Absolute Altitude: 114.82
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: 162.5
#
# Image: DJI_0698.JPG
#   Latitude: 5.683308333333334
#   Longitude: -0.037747222222222224
#   Relative Altitude: 90.0
#   Absolute Altitude: 114.88
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: 162.4
#
# Image: DJI_0699.JPG
#   Latitude: 5.683177777777778
#   Longitude: -0.03770833333333333
#   Relative Altitude: 89.9
#   Absolute Altitude: 114.91
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: 162.3
#
# Image: DJI_0700.JPG
#   Latitude: 5.683052777777778
#   Longitude: -0.03767222222222222
#   Relative Altitude: 89.9
#   Absolute Altitude: 115.05
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: 162.4
#
# Image: DJI_0701.JPG
#   Latitude: 5.682916666666667
#   Longitude: -0.037630555555555556
#   Relative Altitude: 90.0
#   Absolute Altitude: 115.11
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: 162.5
#
# Image: DJI_0702.JPG
#   Latitude: 5.682794444444445
#   Longitude: -0.037594444444444444
#   Relative Altitude: 90.0
#   Absolute Altitude: 114.94
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: 162.5
#
# Image: DJI_0703.JPG
#   Latitude: 5.682666666666667
#   Longitude: -0.03755555555555556
#   Relative Altitude: 90.0
#   Absolute Altitude: 114.77
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: 162.5
#
# Image: DJI_0704.JPG
#   Latitude: 5.682536111111111
#   Longitude: -0.03751666666666666
#   Relative Altitude: 89.9
#   Absolute Altitude: 114.76
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: 162.7
#
# Image: DJI_0705.JPG
#   Latitude: 5.682408333333334
#   Longitude: -0.037477777777777777
#   Relative Altitude: 90.0
#   Absolute Altitude: 114.79
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: 162.8
#
# Image: DJI_0706.JPG
#   Latitude: 5.682277777777778
#   Longitude: -0.03743888888888889
#   Relative Altitude: 89.9
#   Absolute Altitude: 114.72
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: 162.7
#
# Image: DJI_0707.JPG
#   Latitude: 5.682158333333334
#   Longitude: -0.03740277777777778
#   Relative Altitude: 90.0
#   Absolute Altitude: 114.63
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: 162.5
#
# Image: DJI_0708.JPG
#   Latitude: 5.682025
#   Longitude: -0.03736111111111111
#   Relative Altitude: 89.9
#   Absolute Altitude: 114.52
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: 162.4
#
# Image: DJI_0709.JPG
#   Latitude: 5.681900000000001
#   Longitude: -0.03732222222222222
#   Relative Altitude: 89.8
#   Absolute Altitude: 114.61
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: 162.6
#
# Image: DJI_0710.JPG
#   Latitude: 5.681769444444445
#   Longitude: -0.03728611111111111
#   Relative Altitude: 89.9
#   Absolute Altitude: 114.84
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: 162.7
#
# Image: DJI_0711.JPG
#   Latitude: 5.681638888888889
#   Longitude: -0.03724444444444444
#   Relative Altitude: 89.9
#   Absolute Altitude: 114.88
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: 162.5
#
# Image: DJI_0712.JPG
#   Latitude: 5.681513888888889
#   Longitude: -0.03720833333333333
#   Relative Altitude: 90.0
#   Absolute Altitude: 114.78
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: 162.5
#
# Image: DJI_0713.JPG
#   Latitude: 5.681383333333334
#   Longitude: -0.03716944444444444
#   Relative Altitude: 89.9
#   Absolute Altitude: 114.75
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: 162.4
#
# Image: DJI_0714.JPG
#   Latitude: 5.681252777777778
#   Longitude: -0.037130555555555556
#   Relative Altitude: 90.0
#   Absolute Altitude: 114.74
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: 163.2
#
# Image: DJI_0715.JPG
#   Latitude: 5.681194444444444
#   Longitude: -0.037144444444444445
#   Relative Altitude: 90.0
#   Absolute Altitude: 114.78
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: 173.5
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: 179.8
#
# Image: DJI_0716.JPG
#   Latitude: 5.681177777777778
#   Longitude: -0.037366666666666666
#   Relative Altitude: 90.3
#   Absolute Altitude: 114.08
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -7.4
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: -16.7
#
# Image: DJI_0717.JPG
#   Latitude: 5.6813
#   Longitude: -0.03740277777777778
#   Relative Altitude: 90.3
#   Absolute Altitude: 113.5
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -7.0
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: -17.0
#
# Image: DJI_0718.JPG
#   Latitude: 5.681425
#   Longitude: -0.037441666666666665
#   Relative Altitude: 90.2
#   Absolute Altitude: 112.82
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.8
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: -17.3
#
# Image: DJI_0719.JPG
#   Latitude: 5.6815500000000005
#   Longitude: -0.03748055555555556
#   Relative Altitude: 90.1
#   Absolute Altitude: 112.47
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.7
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: -17.2
#
# Image: DJI_0720.JPG
#   Latitude: 5.681677777777778
#   Longitude: -0.037519444444444446
#   Relative Altitude: 90.0
#   Absolute Altitude: 112.39
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.7
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: -17.3
#
# Image: DJI_0721.JPG
#   Latitude: 5.681808333333334
#   Longitude: -0.03755833333333333
#   Relative Altitude: 90.0
#   Absolute Altitude: 112.55
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.6
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: -16.9
#
# Image: DJI_0722.JPG
#   Latitude: 5.681936111111112
#   Longitude: -0.03759722222222222
#   Relative Altitude: 90.1
#   Absolute Altitude: 112.62
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.6
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: -16.9
#
# Image: DJI_0723.JPG
#   Latitude: 5.682063888888889
#   Longitude: -0.03763611111111111
#   Relative Altitude: 90.1
#   Absolute Altitude: 112.45
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.6
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: -16.8
#
# Image: DJI_0724.JPG
#   Latitude: 5.682194444444445
#   Longitude: -0.03767222222222222
#   Relative Altitude: 90.0
#   Absolute Altitude: 112.5
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.6
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: -16.9
#
# Image: DJI_0725.JPG
#   Latitude: 5.682322222222223
#   Longitude: -0.03771388888888889
#   Relative Altitude: 89.9
#   Absolute Altitude: 112.7
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.6
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: -17.0
#
# Image: DJI_0726.JPG
#   Latitude: 5.682444444444445
#   Longitude: -0.03775
#   Relative Altitude: 90.0
#   Absolute Altitude: 112.89
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.6
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: -16.9
#
# Image: DJI_0727.JPG
#   Latitude: 5.682575
#   Longitude: -0.037788888888888886
#   Relative Altitude: 90.0
#   Absolute Altitude: 112.93
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.6
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: -16.8
#
# Image: DJI_0728.JPG
#   Latitude: 5.682708333333333
#   Longitude: -0.037830555555555555
#   Relative Altitude: 89.9
#   Absolute Altitude: 112.95
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.6
#   Gimbal Pitch Degree: -89.9
#   Flight Yaw Degree: -16.9
#
# Image: DJI_0729.JPG
#   Latitude: 5.682833333333334
#   Longitude: -0.037866666666666667
#   Relative Altitude: 90.0
#   Absolute Altitude: 112.85
#   GSD: 0.022
#   Gimbal Roll Degree: 0.0
#   Gimbal Yaw Degree: -6.6
#   Gimbal Pitch Degree: -90.0
#   Flight Yaw Degree: -17.0

# %% [markdown]
# ### ORB

# %%
import os
import cv2
import numpy as np
from skimage import io
from skimage.registration import phase_cross_correlation
from skimage.transform import rotate

def preprocess_image(image):
    """Preprocess the image by converting it to grayscale and normalizing."""
    if image.ndim == 3:
        image = image.mean(axis=2)  # Convert to grayscale by averaging color channels
    return image.astype(np.float32) / 255.0  # Normalize the image

def rotate_shift(shift, yaw):
    """Apply yaw rotation to the shift vector."""
    yaw_rad = math.radians(yaw)
    rotation_matrix = np.array([
        [math.cos(yaw_rad), -math.sin(yaw_rad)],
        [math.sin(yaw_rad), math.cos(yaw_rad)]
    ])
    return rotation_matrix.dot(shift)

def estimate_shift_orb(image1, image2):
    """Estimate shift between two images using ORB feature matching."""
    
    # Convert to grayscale
    gray1 = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
    gray2 = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY)

    # Initialize ORB detector
    orb = cv2.ORB_create(nfeatures=5000)  # Increase features for more robust matching

    # Detect keypoints and descriptors
    keypoints1, descriptors1 = orb.detectAndCompute(gray1, None)
    keypoints2, descriptors2 = orb.detectAndCompute(gray2, None)

    # Use FLANN based matcher
    bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
    matches = bf.match(descriptors1, descriptors2)

    # Sort matches by distance
    matches = sorted(matches, key=lambda x: x.distance)

    # Extract matched keypoints
    points1 = np.float32([keypoints1[m.queryIdx].pt for m in matches])
    points2 = np.float32([keypoints2[m.trainIdx].pt for m in matches])

    # Compute the median shift
    shift_x = np.median(points2[:, 0] - points1[:, 0])
    shift_y = np.median(points2[:, 1] - points1[:, 1])

    print(f"Estimated Shift: x={shift_x:.2f}, y={shift_y:.2f}")

    return shift_x, shift_y

def estimate_shift_phase_correlation(image1, image2, yaw1, yaw2):
    """Estimate shift using phase cross-correlation if rotation is detected."""
    image1 = preprocess_image(image1)
    image2 = preprocess_image(image2)

    # Compute the initial pixel shift using cross-correlation
    shift, _, _ = phase_cross_correlation(image1, image2, upsample_factor=10)

    # Detect if there’s a direction change
    yaw_diff = yaw2 - yaw1
    print("yaw_diff", yaw_diff)
    rotation_detected = abs(yaw_diff) > 1  # Small threshold to account for noise
    corrected_shift = shift   # Initialize corrected shift

    rotation_angle = 0.0
    if rotation_detected:
        # Estimate the rotation angle based on yaw difference
        rotation_angle = yaw_diff
        
        # Rotate the second image for alignment
        image2_rotated = rotate(image2, angle=-rotation_angle, resize=False)
        
        # Recompute the shift after rotation correction
        corrected_shift, _, _ = phase_cross_correlation(image1, image2_rotated, upsample_factor=10)

    # Apply yaw correction to the shift vector
    corrected_shift = rotate_shift(corrected_shift, yaw_diff)

    return corrected_shift[0], corrected_shift[1]  # Return y, x shift

def process_image_folder_with_orb_and_phase_correlation(folder_path, image_metadata):
    """Process all images in the folder, estimating shifts using ORB and phase cross-correlation."""
    images = sorted([f for f in os.listdir(folder_path) if f.endswith(('.jpg', '.JPG', '.png', '.jpeg'))])
    results = {}

    for i in range(len(images) - 1):
        img1_path = os.path.join(folder_path, images[i])
        img2_path = os.path.join(folder_path, images[i + 1])

        image1 = io.imread(img1_path)
        image2 = io.imread(img2_path)
        # Get yaw angles from metadata
        yaw1 = image_metadata.get(images[i], {}).get('Gimbal Yaw Degree', 0)
        yaw2 = image_metadata.get(images[i + 1], {}).get('Gimbal Yaw Degree', 0)

        yaw_diff = yaw2 - yaw1
        print(f"Yaw Difference between {images[i]} and {images[i+1]}: {yaw_diff:.2f}°")

        if abs(yaw_diff) > 1:  # Use phase cross-correlation if rotation is detected
            shift_y, shift_x = estimate_shift_phase_correlation(image1, image2, yaw1, yaw2)
        else:  # Use ORB for shift estimation if no significant rotation
            shift_x, shift_y = estimate_shift_orb(image1, image2)

        results[f"{images[i]}_{images[i+1]}"] = {
            "shift": {"y": shift_y, "x": shift_x},
            "rotation_angle": yaw_diff
        }

        print(f"Between {images[i]} and {images[i+1]}: Shift (y, x) = {shift_y:.2f}, {shift_x:.2f}")

    return results

# Example Usage:
shift_results = process_image_folder_with_orb_and_phase_correlation(image_folder_path, image_metadata)
# Out:
# Yaw Difference between DJI_0613.JPG and DJI_0614.JPG: 0.00°
# Estimated Shift: x=-21.36, y=683.79
# Between DJI_0613.JPG and DJI_0614.JPG: Shift (y, x) = 683.79, -21.36
# Yaw Difference between DJI_0614.JPG and DJI_0615.JPG: 0.00°
# Estimated Shift: x=-1.44, y=686.00
# Between DJI_0614.JPG and DJI_0615.JPG: Shift (y, x) = 686.00, -1.44
# Yaw Difference between DJI_0615.JPG and DJI_0616.JPG: 0.00°
# Estimated Shift: x=-32.85, y=711.63
# Between DJI_0615.JPG and DJI_0616.JPG: Shift (y, x) = 711.63, -32.85
# Yaw Difference between DJI_0616.JPG and DJI_0617.JPG: 0.00°
# Estimated Shift: x=-38.21, y=675.65
# Between DJI_0616.JPG and DJI_0617.JPG: Shift (y, x) = 675.65, -38.21
# Yaw Difference between DJI_0617.JPG and DJI_0618.JPG: 0.00°
# Estimated Shift: x=-28.80, y=664.00
# Between DJI_0617.JPG and DJI_0618.JPG: Shift (y, x) = 664.00, -28.80
# Yaw Difference between DJI_0618.JPG and DJI_0619.JPG: 0.00°
# Estimated Shift: x=-10.37, y=690.09
# Between DJI_0618.JPG and DJI_0619.JPG: Shift (y, x) = 690.09, -10.37
# Yaw Difference between DJI_0619.JPG and DJI_0620.JPG: 0.00°
# Estimated Shift: x=55.99, y=686.40
# Between DJI_0619.JPG and DJI_0620.JPG: Shift (y, x) = 686.40, 55.99
# Yaw Difference between DJI_0620.JPG and DJI_0621.JPG: 0.00°
# Estimated Shift: x=36.29, y=676.68
# Between DJI_0620.JPG and DJI_0621.JPG: Shift (y, x) = 676.68, 36.29
# Yaw Difference between DJI_0621.JPG and DJI_0622.JPG: 0.00°
# Estimated Shift: x=116.00, y=675.65
# Between DJI_0621.JPG and DJI_0622.JPG: Shift (y, x) = 675.65, 116.00
# Yaw Difference between DJI_0622.JPG and DJI_0623.JPG: 0.00°
# Estimated Shift: x=23.89, y=659.90
# Between DJI_0622.JPG and DJI_0623.JPG: Shift (y, x) = 659.90, 23.89
# Yaw Difference between DJI_0623.JPG and DJI_0624.JPG: 0.00°
# Estimated Shift: x=60.48, y=660.10
# Between DJI_0623.JPG and DJI_0624.JPG: Shift (y, x) = 660.10, 60.48
# Yaw Difference between DJI_0624.JPG and DJI_0625.JPG: 0.00°
# Estimated Shift: x=65.69, y=608.26
# Between DJI_0624.JPG and DJI_0625.JPG: Shift (y, x) = 608.26, 65.69
# Yaw Difference between DJI_0625.JPG and DJI_0626.JPG: -180.90°
# yaw_diff -180.9
# Between DJI_0625.JPG and DJI_0626.JPG: Shift (y, x) = -1734.99, 27.26
# Yaw Difference between DJI_0626.JPG and DJI_0627.JPG: 0.40°
# Estimated Shift: x=102.01, y=630.72
# Between DJI_0626.JPG and DJI_0627.JPG: Shift (y, x) = 630.72, 102.01
# Yaw Difference between DJI_0627.JPG and DJI_0628.JPG: 0.20°
# Estimated Shift: x=87.09, y=651.53
# Between DJI_0627.JPG and DJI_0628.JPG: Shift (y, x) = 651.53, 87.09
# Yaw Difference between DJI_0628.JPG and DJI_0629.JPG: 0.10°
# Estimated Shift: x=39.41, y=659.41
# Between DJI_0628.JPG and DJI_0629.JPG: Shift (y, x) = 659.41, 39.41
# Yaw Difference between DJI_0629.JPG and DJI_0630.JPG: 0.00°
# Estimated Shift: x=10.37, y=691.65
# Between DJI_0629.JPG and DJI_0630.JPG: Shift (y, x) = 691.65, 10.37
# Yaw Difference between DJI_0630.JPG and DJI_0631.JPG: 0.10°
# Estimated Shift: x=-8.00, y=671.85
# Between DJI_0630.JPG and DJI_0631.JPG: Shift (y, x) = 671.85, -8.00
# Yaw Difference between DJI_0631.JPG and DJI_0632.JPG: 0.00°
# Estimated Shift: x=-2.88, y=710.95
# Between DJI_0631.JPG and DJI_0632.JPG: Shift (y, x) = 710.95, -2.88
# Yaw Difference between DJI_0632.JPG and DJI_0633.JPG: 0.00°
# Estimated Shift: x=-4.00, y=694.24
# Between DJI_0632.JPG and DJI_0633.JPG: Shift (y, x) = 694.24, -4.00
# Yaw Difference between DJI_0633.JPG and DJI_0634.JPG: 0.00°
# Estimated Shift: x=-21.60, y=743.04
# Between DJI_0633.JPG and DJI_0634.JPG: Shift (y, x) = 743.04, -21.60
# Yaw Difference between DJI_0634.JPG and DJI_0635.JPG: 0.00°
# Estimated Shift: x=-14.93, y=712.12
# Between DJI_0634.JPG and DJI_0635.JPG: Shift (y, x) = 712.12, -14.93
# Yaw Difference between DJI_0635.JPG and DJI_0636.JPG: 0.00°
# Estimated Shift: x=0.00, y=709.20
# Between DJI_0635.JPG and DJI_0636.JPG: Shift (y, x) = 709.20, 0.00
# Yaw Difference between DJI_0636.JPG and DJI_0637.JPG: 0.00°
# Estimated Shift: x=-4.06, y=732.96
# Between DJI_0636.JPG and DJI_0637.JPG: Shift (y, x) = 732.96, -4.06
# Yaw Difference between DJI_0637.JPG and DJI_0638.JPG: 0.00°
# Estimated Shift: x=-12.90, y=734.40
# Between DJI_0637.JPG and DJI_0638.JPG: Shift (y, x) = 734.40, -12.90
# Yaw Difference between DJI_0638.JPG and DJI_0639.JPG: 0.00°
# Estimated Shift: x=-2.99, y=729.95
# Between DJI_0638.JPG and DJI_0639.JPG: Shift (y, x) = 729.95, -2.99
# Yaw Difference between DJI_0639.JPG and DJI_0640.JPG: 0.00°
# Estimated Shift: x=0.00, y=758.00
# Between DJI_0639.JPG and DJI_0640.JPG: Shift (y, x) = 758.00, 0.00
# Yaw Difference between DJI_0640.JPG and DJI_0641.JPG: 0.10°
# Estimated Shift: x=-2.99, y=711.24
# Between DJI_0640.JPG and DJI_0641.JPG: Shift (y, x) = 711.24, -2.99
# Yaw Difference between DJI_0641.JPG and DJI_0642.JPG: 0.00°
# Estimated Shift: x=-7.00, y=743.51
# Between DJI_0641.JPG and DJI_0642.JPG: Shift (y, x) = 743.51, -7.00
# Yaw Difference between DJI_0642.JPG and DJI_0643.JPG: 0.00°
# Estimated Shift: x=-12.00, y=740.16
# Between DJI_0642.JPG and DJI_0643.JPG: Shift (y, x) = 740.16, -12.00
# Yaw Difference between DJI_0643.JPG and DJI_0644.JPG: 0.00°
# Estimated Shift: x=-4.15, y=751.84
# Between DJI_0643.JPG and DJI_0644.JPG: Shift (y, x) = 751.84, -4.15
# Yaw Difference between DJI_0644.JPG and DJI_0645.JPG: 0.00°
# Estimated Shift: x=1.73, y=748.57
# Between DJI_0644.JPG and DJI_0645.JPG: Shift (y, x) = 748.57, 1.73
# Yaw Difference between DJI_0645.JPG and DJI_0646.JPG: 0.00°
# Estimated Shift: x=-1.20, y=761.76
# Between DJI_0645.JPG and DJI_0646.JPG: Shift (y, x) = 761.76, -1.20
# Yaw Difference between DJI_0646.JPG and DJI_0647.JPG: 0.00°
# Estimated Shift: x=-15.60, y=756.86
# Between DJI_0646.JPG and DJI_0647.JPG: Shift (y, x) = 756.86, -15.60
# Yaw Difference between DJI_0647.JPG and DJI_0648.JPG: 0.00°
# Estimated Shift: x=-29.00, y=751.84
# Between DJI_0647.JPG and DJI_0648.JPG: Shift (y, x) = 751.84, -29.00
# Yaw Difference between DJI_0648.JPG and DJI_0649.JPG: 0.00°
# Estimated Shift: x=-10.08, y=775.68
# Between DJI_0648.JPG and DJI_0649.JPG: Shift (y, x) = 775.68, -10.08
# Yaw Difference between DJI_0649.JPG and DJI_0650.JPG: 0.00°
# Estimated Shift: x=-3.46, y=806.00
# Between DJI_0649.JPG and DJI_0650.JPG: Shift (y, x) = 806.00, -3.46
# Yaw Difference between DJI_0650.JPG and DJI_0651.JPG: 0.00°
# Estimated Shift: x=-3.00, y=770.00
# Between DJI_0650.JPG and DJI_0651.JPG: Shift (y, x) = 770.00, -3.00
# Yaw Difference between DJI_0651.JPG and DJI_0652.JPG: 0.00°
# Estimated Shift: x=-5.97, y=750.64
# Between DJI_0651.JPG and DJI_0652.JPG: Shift (y, x) = 750.64, -5.97
# Yaw Difference between DJI_0652.JPG and DJI_0653.JPG: 0.00°
# Estimated Shift: x=-21.55, y=771.38
# Between DJI_0652.JPG and DJI_0653.JPG: Shift (y, x) = 771.38, -21.55
# Yaw Difference between DJI_0653.JPG and DJI_0654.JPG: 0.00°
# Estimated Shift: x=-20.16, y=788.30
# Between DJI_0653.JPG and DJI_0654.JPG: Shift (y, x) = 788.30, -20.16
# Yaw Difference between DJI_0654.JPG and DJI_0655.JPG: 0.00°
# Estimated Shift: x=-18.72, y=795.47
# Between DJI_0654.JPG and DJI_0655.JPG: Shift (y, x) = 795.47, -18.72
# Yaw Difference between DJI_0655.JPG and DJI_0656.JPG: 0.00°
# Estimated Shift: x=-24.00, y=811.85
# Between DJI_0655.JPG and DJI_0656.JPG: Shift (y, x) = 811.85, -24.00
# Yaw Difference between DJI_0656.JPG and DJI_0657.JPG: 0.00°
# Estimated Shift: x=-19.00, y=799.70
# Between DJI_0656.JPG and DJI_0657.JPG: Shift (y, x) = 799.70, -19.00
# Yaw Difference between DJI_0657.JPG and DJI_0658.JPG: 0.00°
# Estimated Shift: x=-18.72, y=818.16
# Between DJI_0657.JPG and DJI_0658.JPG: Shift (y, x) = 818.16, -18.72
# Yaw Difference between DJI_0658.JPG and DJI_0659.JPG: 0.00°
# Estimated Shift: x=-24.48, y=808.70
# Between DJI_0658.JPG and DJI_0659.JPG: Shift (y, x) = 808.70, -24.48
# Yaw Difference between DJI_0659.JPG and DJI_0660.JPG: 0.00°
# Estimated Shift: x=-24.00, y=809.30
# Between DJI_0659.JPG and DJI_0660.JPG: Shift (y, x) = 809.30, -24.00
# Yaw Difference between DJI_0660.JPG and DJI_0661.JPG: 0.00°
# Estimated Shift: x=-27.00, y=811.40
# Between DJI_0660.JPG and DJI_0661.JPG: Shift (y, x) = 811.40, -27.00
# Yaw Difference between DJI_0661.JPG and DJI_0662.JPG: 0.00°
# Estimated Shift: x=-23.00, y=830.00
# Between DJI_0661.JPG and DJI_0662.JPG: Shift (y, x) = 830.00, -23.00
# Yaw Difference between DJI_0662.JPG and DJI_0663.JPG: 0.00°
# Estimated Shift: x=-17.92, y=800.32
# Between DJI_0662.JPG and DJI_0663.JPG: Shift (y, x) = 800.32, -17.92
# Yaw Difference between DJI_0663.JPG and DJI_0664.JPG: 0.00°
# Estimated Shift: x=-19.91, y=828.00
# Between DJI_0663.JPG and DJI_0664.JPG: Shift (y, x) = 828.00, -19.91
# Yaw Difference between DJI_0664.JPG and DJI_0665.JPG: 0.00°
# Estimated Shift: x=-24.19, y=849.60
# Between DJI_0664.JPG and DJI_0665.JPG: Shift (y, x) = 849.60, -24.19
# Yaw Difference between DJI_0665.JPG and DJI_0666.JPG: 0.00°
# Estimated Shift: x=-32.00, y=808.70
# Between DJI_0665.JPG and DJI_0666.JPG: Shift (y, x) = 808.70, -32.00
# Yaw Difference between DJI_0666.JPG and DJI_0667.JPG: 0.00°
# Estimated Shift: x=-29.86, y=815.62
# Between DJI_0666.JPG and DJI_0667.JPG: Shift (y, x) = 815.62, -29.86
# Yaw Difference between DJI_0667.JPG and DJI_0668.JPG: 0.00°
# Estimated Shift: x=-25.00, y=803.52
# Between DJI_0667.JPG and DJI_0668.JPG: Shift (y, x) = 803.52, -25.00
# Yaw Difference between DJI_0668.JPG and DJI_0669.JPG: 0.00°
# Estimated Shift: x=-26.87, y=838.08
# Between DJI_0668.JPG and DJI_0669.JPG: Shift (y, x) = 838.08, -26.87
# Yaw Difference between DJI_0669.JPG and DJI_0670.JPG: 0.00°
# Estimated Shift: x=109.91, y=350.10
# Between DJI_0669.JPG and DJI_0670.JPG: Shift (y, x) = 350.10, 109.91
# Yaw Difference between DJI_0670.JPG and DJI_0671.JPG: 180.80°
# yaw_diff 180.8
# Between DJI_0670.JPG and DJI_0671.JPG: Shift (y, x) = 1516.15, 21.17
# Yaw Difference between DJI_0671.JPG and DJI_0672.JPG: -0.40°
# Estimated Shift: x=-74.65, y=724.32
# Between DJI_0671.JPG and DJI_0672.JPG: Shift (y, x) = 724.32, -74.65
# Yaw Difference between DJI_0672.JPG and DJI_0673.JPG: -0.20°
# Estimated Shift: x=-72.16, y=796.61
# Between DJI_0672.JPG and DJI_0673.JPG: Shift (y, x) = 796.61, -72.16
# Yaw Difference between DJI_0673.JPG and DJI_0674.JPG: -0.10°
# Estimated Shift: x=-44.79, y=781.33
# Between DJI_0673.JPG and DJI_0674.JPG: Shift (y, x) = 781.33, -44.79
# Yaw Difference between DJI_0674.JPG and DJI_0675.JPG: 0.00°
# Estimated Shift: x=-24.48, y=801.79
# Between DJI_0674.JPG and DJI_0675.JPG: Shift (y, x) = 801.79, -24.48
# Yaw Difference between DJI_0675.JPG and DJI_0676.JPG: 0.00°
# Estimated Shift: x=-17.92, y=771.52
# Between DJI_0675.JPG and DJI_0676.JPG: Shift (y, x) = 771.52, -17.92
# Yaw Difference between DJI_0676.JPG and DJI_0677.JPG: -0.10°
# Estimated Shift: x=0.00, y=792.58
# Between DJI_0676.JPG and DJI_0677.JPG: Shift (y, x) = 792.58, 0.00
# Yaw Difference between DJI_0677.JPG and DJI_0678.JPG: 0.00°
# Estimated Shift: x=2.88, y=841.05
# Between DJI_0677.JPG and DJI_0678.JPG: Shift (y, x) = 841.05, 2.88
# Yaw Difference between DJI_0678.JPG and DJI_0679.JPG: 0.00°
# Estimated Shift: x=-8.13, y=789.60
# Between DJI_0678.JPG and DJI_0679.JPG: Shift (y, x) = 789.60, -8.13
# Yaw Difference between DJI_0679.JPG and DJI_0680.JPG: 0.00°
# Estimated Shift: x=-23.04, y=792.00
# Between DJI_0679.JPG and DJI_0680.JPG: Shift (y, x) = 792.00, -23.04
# Yaw Difference between DJI_0680.JPG and DJI_0681.JPG: 0.00°
# Estimated Shift: x=-5.76, y=792.58
# Between DJI_0680.JPG and DJI_0681.JPG: Shift (y, x) = 792.58, -5.76
# Yaw Difference between DJI_0681.JPG and DJI_0682.JPG: 0.00°
# Estimated Shift: x=64.50, y=786.00
# Between DJI_0681.JPG and DJI_0682.JPG: Shift (y, x) = 786.00, 64.50
# Yaw Difference between DJI_0682.JPG and DJI_0683.JPG: 0.00°
# Estimated Shift: x=26.41, y=790.00
# Between DJI_0682.JPG and DJI_0683.JPG: Shift (y, x) = 790.00, 26.41
# Yaw Difference between DJI_0683.JPG and DJI_0684.JPG: 0.00°
# Estimated Shift: x=32.35, y=766.94
# Between DJI_0683.JPG and DJI_0684.JPG: Shift (y, x) = 766.94, 32.35
# Yaw Difference between DJI_0684.JPG and DJI_0685.JPG: 0.00°
# Estimated Shift: x=23.04, y=782.40
# Between DJI_0684.JPG and DJI_0685.JPG: Shift (y, x) = 782.40, 23.04
# Yaw Difference between DJI_0685.JPG and DJI_0686.JPG: 0.00°
# Estimated Shift: x=28.00, y=776.16
# Between DJI_0685.JPG and DJI_0686.JPG: Shift (y, x) = 776.16, 28.00
# Yaw Difference between DJI_0686.JPG and DJI_0687.JPG: 0.00°
# Estimated Shift: x=8.64, y=767.52
# Between DJI_0686.JPG and DJI_0687.JPG: Shift (y, x) = 767.52, 8.64
# Yaw Difference between DJI_0687.JPG and DJI_0688.JPG: 0.00°
# Estimated Shift: x=12.00, y=764.41
# Between DJI_0687.JPG and DJI_0688.JPG: Shift (y, x) = 764.41, 12.00
# Yaw Difference between DJI_0688.JPG and DJI_0689.JPG: 0.00°
# Estimated Shift: x=7.46, y=764.41
# Between DJI_0688.JPG and DJI_0689.JPG: Shift (y, x) = 764.41, 7.46
# Yaw Difference between DJI_0689.JPG and DJI_0690.JPG: 0.00°
# Estimated Shift: x=25.92, y=783.82
# Between DJI_0689.JPG and DJI_0690.JPG: Shift (y, x) = 783.82, 25.92
# Yaw Difference between DJI_0690.JPG and DJI_0691.JPG: 0.00°
# Estimated Shift: x=2.88, y=767.23
# Between DJI_0690.JPG and DJI_0691.JPG: Shift (y, x) = 767.23, 2.88
# Yaw Difference between DJI_0691.JPG and DJI_0692.JPG: 0.00°
# Estimated Shift: x=21.00, y=763.20
# Between DJI_0691.JPG and DJI_0692.JPG: Shift (y, x) = 763.20, 21.00
# Yaw Difference between DJI_0692.JPG and DJI_0693.JPG: 0.00°
# Estimated Shift: x=-2.07, y=727.20
# Between DJI_0692.JPG and DJI_0693.JPG: Shift (y, x) = 727.20, -2.07
# Yaw Difference between DJI_0693.JPG and DJI_0694.JPG: 0.00°
# Estimated Shift: x=-43.55, y=757.44
# Between DJI_0693.JPG and DJI_0694.JPG: Shift (y, x) = 757.44, -43.55
# Yaw Difference between DJI_0694.JPG and DJI_0695.JPG: 0.00°
# Estimated Shift: x=-6.00, y=726.59
# Between DJI_0694.JPG and DJI_0695.JPG: Shift (y, x) = 726.59, -6.00
# Yaw Difference between DJI_0695.JPG and DJI_0696.JPG: 0.00°
# Estimated Shift: x=-32.83, y=738.20
# Between DJI_0695.JPG and DJI_0696.JPG: Shift (y, x) = 738.20, -32.83
# Yaw Difference between DJI_0696.JPG and DJI_0697.JPG: 0.00°
# Estimated Shift: x=-50.11, y=728.64
# Between DJI_0696.JPG and DJI_0697.JPG: Shift (y, x) = 728.64, -50.11
# Yaw Difference between DJI_0697.JPG and DJI_0698.JPG: 0.00°
# Estimated Shift: x=-32.83, y=701.71
# Between DJI_0697.JPG and DJI_0698.JPG: Shift (y, x) = 701.71, -32.83
# Yaw Difference between DJI_0698.JPG and DJI_0699.JPG: 0.00°
# Estimated Shift: x=-29.86, y=698.80
# Between DJI_0698.JPG and DJI_0699.JPG: Shift (y, x) = 698.80, -29.86
# Yaw Difference between DJI_0699.JPG and DJI_0700.JPG: 0.00°
# Estimated Shift: x=-49.20, y=687.97
# Between DJI_0699.JPG and DJI_0700.JPG: Shift (y, x) = 687.97, -49.20
# Yaw Difference between DJI_0700.JPG and DJI_0701.JPG: 0.00°
# Estimated Shift: x=-25.92, y=716.92
# Between DJI_0700.JPG and DJI_0701.JPG: Shift (y, x) = 716.92, -25.92
# Yaw Difference between DJI_0701.JPG and DJI_0702.JPG: 0.00°
# Estimated Shift: x=11.52, y=684.00
# Between DJI_0701.JPG and DJI_0702.JPG: Shift (y, x) = 684.00, 11.52
# Yaw Difference between DJI_0702.JPG and DJI_0703.JPG: 0.00°
# Estimated Shift: x=18.66, y=685.44
# Between DJI_0702.JPG and DJI_0703.JPG: Shift (y, x) = 685.44, 18.66
# Yaw Difference between DJI_0703.JPG and DJI_0704.JPG: 0.00°
# Estimated Shift: x=29.03, y=674.80
# Between DJI_0703.JPG and DJI_0704.JPG: Shift (y, x) = 674.80, 29.03
# Yaw Difference between DJI_0704.JPG and DJI_0705.JPG: 0.00°
# Estimated Shift: x=48.75, y=686.20
# Between DJI_0704.JPG and DJI_0705.JPG: Shift (y, x) = 686.20, 48.75
# Yaw Difference between DJI_0705.JPG and DJI_0706.JPG: 0.00°
# Estimated Shift: x=114.05, y=685.20
# Between DJI_0705.JPG and DJI_0706.JPG: Shift (y, x) = 685.20, 114.05
# Yaw Difference between DJI_0706.JPG and DJI_0707.JPG: 0.00°
# Estimated Shift: x=112.32, y=672.48
# Between DJI_0706.JPG and DJI_0707.JPG: Shift (y, x) = 672.48, 112.32
# Yaw Difference between DJI_0707.JPG and DJI_0708.JPG: 0.00°
# Estimated Shift: x=31.10, y=705.60
# Between DJI_0707.JPG and DJI_0708.JPG: Shift (y, x) = 705.60, 31.10
# Yaw Difference between DJI_0708.JPG and DJI_0709.JPG: 0.00°
# Estimated Shift: x=-39.42, y=682.56
# Between DJI_0708.JPG and DJI_0709.JPG: Shift (y, x) = 682.56, -39.42
# Yaw Difference between DJI_0709.JPG and DJI_0710.JPG: 0.00°
# Estimated Shift: x=-21.60, y=681.60
# Between DJI_0709.JPG and DJI_0710.JPG: Shift (y, x) = 681.60, -21.60
# Yaw Difference between DJI_0710.JPG and DJI_0711.JPG: 0.00°
# Estimated Shift: x=10.37, y=706.80
# Between DJI_0710.JPG and DJI_0711.JPG: Shift (y, x) = 706.80, 10.37
# Yaw Difference between DJI_0711.JPG and DJI_0712.JPG: 0.00°
# Estimated Shift: x=15.84, y=684.00
# Between DJI_0711.JPG and DJI_0712.JPG: Shift (y, x) = 684.00, 15.84
# Yaw Difference between DJI_0712.JPG and DJI_0713.JPG: 0.00°
# Estimated Shift: x=26.40, y=691.20
# Between DJI_0712.JPG and DJI_0713.JPG: Shift (y, x) = 691.20, 26.40
# Yaw Difference between DJI_0713.JPG and DJI_0714.JPG: 0.00°
# Estimated Shift: x=37.32, y=686.78
# Between DJI_0713.JPG and DJI_0714.JPG: Shift (y, x) = 686.78, 37.32
# Yaw Difference between DJI_0714.JPG and DJI_0715.JPG: 0.00°
# Estimated Shift: x=-32.00, y=357.70
# Between DJI_0714.JPG and DJI_0715.JPG: Shift (y, x) = 357.70, -32.00
# Yaw Difference between DJI_0715.JPG and DJI_0716.JPG: -180.90°
# yaw_diff -180.9
# Between DJI_0715.JPG and DJI_0716.JPG: Shift (y, x) = -15.30, 0.14
# Yaw Difference between DJI_0716.JPG and DJI_0717.JPG: 0.40°
# Estimated Shift: x=77.64, y=618.10
# Between DJI_0716.JPG and DJI_0717.JPG: Shift (y, x) = 618.10, 77.64
# Yaw Difference between DJI_0717.JPG and DJI_0718.JPG: 0.20°
# Estimated Shift: x=86.40, y=646.08
# Between DJI_0717.JPG and DJI_0718.JPG: Shift (y, x) = 646.08, 86.40
# Yaw Difference between DJI_0718.JPG and DJI_0719.JPG: 0.10°
# Estimated Shift: x=52.80, y=677.00
# Between DJI_0718.JPG and DJI_0719.JPG: Shift (y, x) = 677.00, 52.80
# Yaw Difference between DJI_0719.JPG and DJI_0720.JPG: 0.00°
# Estimated Shift: x=23.89, y=683.04
# Between DJI_0719.JPG and DJI_0720.JPG: Shift (y, x) = 683.04, 23.89
# Yaw Difference between DJI_0720.JPG and DJI_0721.JPG: 0.10°
# Estimated Shift: x=17.42, y=717.47
# Between DJI_0720.JPG and DJI_0721.JPG: Shift (y, x) = 717.47, 17.42
# Yaw Difference between DJI_0721.JPG and DJI_0722.JPG: 0.00°
# Estimated Shift: x=5.97, y=717.12
# Between DJI_0721.JPG and DJI_0722.JPG: Shift (y, x) = 717.12, 5.97
# Yaw Difference between DJI_0722.JPG and DJI_0723.JPG: 0.00°
# Estimated Shift: x=-3.00, y=704.40
# Between DJI_0722.JPG and DJI_0723.JPG: Shift (y, x) = 704.40, -3.00
# Yaw Difference between DJI_0723.JPG and DJI_0724.JPG: 0.00°
# Estimated Shift: x=-11.10, y=731.12
# Between DJI_0723.JPG and DJI_0724.JPG: Shift (y, x) = 731.12, -11.10
# Yaw Difference between DJI_0724.JPG and DJI_0725.JPG: 0.00°
# Estimated Shift: x=-2.99, y=719.00
# Between DJI_0724.JPG and DJI_0725.JPG: Shift (y, x) = 719.00, -2.99
# Yaw Difference between DJI_0725.JPG and DJI_0726.JPG: 0.00°
# Estimated Shift: x=-9.60, y=717.60
# Between DJI_0725.JPG and DJI_0726.JPG: Shift (y, x) = 717.60, -9.60
# Yaw Difference between DJI_0726.JPG and DJI_0727.JPG: 0.00°
# Estimated Shift: x=1.44, y=723.74
# Between DJI_0726.JPG and DJI_0727.JPG: Shift (y, x) = 723.74, 1.44
# Yaw Difference between DJI_0727.JPG and DJI_0728.JPG: 0.00°
# Estimated Shift: x=-1.44, y=723.60
# Between DJI_0727.JPG and DJI_0728.JPG: Shift (y, x) = 723.60, -1.44
# Yaw Difference between DJI_0728.JPG and DJI_0729.JPG: 0.00°
# Estimated Shift: x=-3.58, y=711.24
# Between DJI_0728.JPG and DJI_0729.JPG: Shift (y, x) = 711.24, -3.58

# %% [markdown]
# # Bounding Box Matching

# %%
import os
import csv
import pandas as pd
import numpy as np
from shapely.geometry import box
import cv2
import matplotlib.pyplot as plt


def apply_shift_and_rotation(bbox, shift, rotation_angle, image_shape):
    """Applies shift and 180-degree rotation to a bounding box."""
    x, y, width, height = bbox
    image_width, image_height = image_shape  # Ensure correctly passed as (w, h)
    
    center_x, center_y = image_width / 2, image_height / 2  # Compute image center

    x_shifted = x - shift['x']
    y_shifted = y - shift['y']

    # Step 2: Apply 180-degree rotation if needed
    if 179 <= abs(rotation_angle) <= 181:  # Allow small variations like 180.7
        x_rotated = 2 * center_x - x_shifted
        y_rotated = 2 * center_y - y_shifted
    else:
        x_rotated, y_rotated = x_shifted, y_shifted  # No rotation applied

    return x_rotated, y_rotated, width, height


def compute_rgb_similarity(cropped1, cropped2):
    """Vergleicht zwei Bildausschnitte basierend auf Durchschnitts-RGB-Werten."""
    # Average color for RGB channels
    avg_color1 = np.mean(cropped1, axis=(0, 1))  # Mittelwert für R, G, B von Bild 1
    avg_color2 = np.mean(cropped2, axis=(0, 1))  # Mittelwert für R, G, B von Bild 2
    
    # euclidean distance between the color values
    color_distance = np.linalg.norm(avg_color1 - avg_color2)
    
    # normalize (max distance = 255 * sqrt(3) if black-white difference)
    max_distance = np.linalg.norm([255, 255, 255])
    similarity = 1 - (color_distance / max_distance)  # Ähnlichkeit zwischen 0 und 1

    # Visualisation (optional)
    """""
    print("compute_rgb_similarity",similarity)
    plt.figure(figsize=(10, 5)) 
    plt.subplot(1, 2, 1)
    plt.imshow(cv2.cvtColor(cropped1, cv2.COLOR_BGR2RGB))
    plt.title("Cropped Image 1")
    plt.axis("off")
    plt.subplot(1, 2, 2)
    plt.imshow(cv2.cvtColor(cropped2, cv2.COLOR_BGR2RGB))
    plt.title("Cropped Image 2")
    plt.axis("off")
    plt.show()
    """""
    return similarity

def convert_bbox_format(bbox):
    x_min = bbox[0] - bbox[2] / 2
    y_min = bbox[1] - bbox[3] / 2
    return [x_min, y_min, bbox[2], bbox[3]]


def compute_iou_and_rgb(bbox1, bbox2, org_bbox2, image1, image2):

    # Convert the bounding boxes to the correct format
    bbox1 = convert_bbox_format(bbox1)
    bbox2 = convert_bbox_format(bbox2)
    org_bbox2 = convert_bbox_format(org_bbox2)
    # Shapley BB Object 
    # Cetner top left corner of the bounding box needed to work with shapely
    box1 = box(bbox1[0], bbox1[1], bbox1[0] + bbox1[2], bbox1[1] + bbox1[3])
    box2 = box(bbox2[0], bbox2[1], bbox2[0] + bbox2[2], bbox2[1] + bbox2[3])
    # Calculate the IoU
    intersection = box1.intersection(box2).area
    union = box1.union(box2).area
    iou = round(intersection / union, 2) if union > 0 else 0

    if iou > 0.5:
        # Extract the bounding box regions from the images
        x1_1, y1_1, x2_1, y2_1 = int(bbox1[0]), int(bbox1[1]), int(bbox1[0] + bbox1[2]), int(bbox1[1] + bbox1[3])
        x1_2, y1_2, x2_2, y2_2 = int(org_bbox2[0]), int(org_bbox2[1]), int(org_bbox2[0] + org_bbox2[2]), int(org_bbox2[1] + org_bbox2[3])
        image1 = cv2.imread(image1)
        image2 = cv2.imread(image2)
        cropped1 = image1[y1_1:y2_1, x1_1:x2_1]
        cropped2 = image2[y1_2:y2_2, x1_2:x2_2]
        # Ensure both crops have the same shape for comparison
        if cropped1.size == 0 or cropped2.size == 0:
            print(f"Error: Empty crop for {image1} or {image2}")

        rgb_similarity = compute_rgb_similarity(cropped1, cropped2)
    else:
        rgb_similarity = 0
    return iou, rgb_similarity

def process_bounding_box_matching(detect_folder_path, image_folder_path, shift_results, iou_threshold=0.5, confidence_threshold=0.5):
    """Processes bounding box matching between previous, current, and next images using shifts."""
    shift_results = {k.lower(): v for k, v in shift_results.items()}  # Convert keys to lowercase for case-insensitive matching
    print("shift_results",shift_results)
    csv_files = sorted([f for f in os.listdir(detect_folder_path) if f.endswith('_detections.csv')])
    #print("csv_files",csv_files)
    # Set zur Speicherung bereits erkannter Bounding Boxes in Case C
    processed_bboxes = set()
    all_matching_results = []
    for i in range(len(csv_files)):
        current_file = csv_files[i]
        # Lade Bounding Boxes für das aktuelle Bild
        current_detections = pd.read_csv(os.path.join(detect_folder_path, current_file))
        current_detections = current_detections[current_detections['confidence'] >= confidence_threshold]

        image_shape = (5472, 3648)  # Ersetze dies durch die tatsächlichen Bildabmessungen, falls verfügbar

        # Verarbeite das erste Bild (nur mit Nachfolger vergleichen) case a
        if i == 0:
            next_file = csv_files[i + 1]
            next_detections = pd.read_csv(os.path.join(detect_folder_path, next_file))
            next_detections = next_detections[next_detections['confidence'] >= confidence_threshold]
            pair_key = f"{current_file.replace('_detections.csv', '').lower()}_{next_file.replace('_detections.csv', '').lower()}"
            print("pair_key",pair_key)
            if pair_key not in shift_results:
                print(f"Case A No shift/rotation data for {pair_key}. Skipping.")
                continue

            shift = shift_results[pair_key]['shift']
            rotation_angle = shift_results[pair_key]['rotation_angle']

            #for rotated images
            if rotation_angle > 175 and rotation_angle < 185:
                #print("Rotated A: shift",shift)
                shift = {'y': -shift['y'],'x': -shift['x']}
                #print("Rotated A: inverse_shift",shift)

            print(f"\nProcessing Case A {current_file} -> {next_file} with shift: {shift} and rotation: {rotation_angle}°")
            #print(current_file, next_file, "current","next")
            image1_path = os.path.join(image_folder_path, current_file.replace('_detections.csv', ''))
            #print("image1",image1_path)
            image2_path = os.path.join(image_folder_path, next_file.replace('_detections.csv', ''))
            #print("image2",image2_path)
            bbm_file = os.path.join(detect_folder_path, f"BBM_{current_file.replace('_detections.csv', '')}.csv")
            with open(bbm_file, 'w', newline='') as csvfile:
                writer = csv.writer(csvfile)
                writer.writerow(["x", "y", "width", "height", "IoU"])

                for _, bbox1 in current_detections.iterrows():
                    bbox1_coords = list(bbox1[['x', 'y', 'width', 'height']].values)
                    
                    for _, bbox2 in next_detections.iterrows():
                        #bbox2_coords are the bbs from the next image
                        bbox2_coords = list(bbox2[['x', 'y', 'width', 'height']].values)
                        transformed_bbox2_coords = list(apply_shift_and_rotation(bbox2_coords, shift, rotation_angle, image_shape))

                        iou, rgb = compute_iou_and_rgb(bbox1_coords, transformed_bbox2_coords, bbox2_coords, image1_path, image2_path)
                        if iou > 0 and iou >= iou_threshold and rgb > 0.95:
                            writer.writerow([bbox1_coords[0], bbox1_coords[1], bbox1_coords[2], bbox1_coords[3], iou])
                            print("Case A",bbox1_coords, iou, rgb)

        # Verarbeite das letzte Bild (nur mit Vorgänger vergleichen) Case b 
        elif i == len(csv_files) - 1:
            prev_file = csv_files[i - 1]
            prev_detections = pd.read_csv(os.path.join(detect_folder_path, prev_file))
            prev_detections = prev_detections[prev_detections['confidence'] >= confidence_threshold]
            pair_key = f"{prev_file.replace('_detections.csv', '').lower()}_{current_file.replace('_detections.csv', '').lower()}"

            if pair_key not in shift_results:
                print(f"Case B No shift/rotation data for {pair_key}. Skipping.")
                continue
            
            shift = shift_results[pair_key]['shift']
            inverse_shift = {'y': -shift['y'],'x': -shift['x']}
            rotation_angle = shift_results[pair_key]['rotation_angle']
            #for rotated images
            #if rotation_angle > 175 and rotation_angle < 185:
            #    print("Rotated B: shift",inverse_shift)
            #    inverse_shift = {'y': shift['y'],'x': shift['x']}
            #    print("Rotated B: inverse_shift",inverse_shift)

            print(f"\nProcessing Case B {current_file} -> {prev_file} with inverted shift: {inverse_shift} and rotation: {rotation_angle}°")
            image1_path = os.path.join(image_folder_path, current_file.replace('_detections.csv', ''))
            image2_path = os.path.join(image_folder_path, prev_file.replace('_detections.csv', ''))
            bbm_file = os.path.join(detect_folder_path, f"BBM_{current_file.replace('_detections.csv', '')}.csv")
            with open(bbm_file, 'w', newline='') as csvfile:
                writer = csv.writer(csvfile)
                writer.writerow(["x", "y", "width", "height", "IoU"])

                for _, bbox1 in current_detections.iterrows():
                    bbox1_coords = list(bbox1[['x', 'y', 'width', 'height']].values)
                    #transformed_bbox1_coords = list(apply_shift_and_rotation(bbox1_coords, inverse_shift, rotation_angle, image_shape))

                    for _, bbox2 in prev_detections.iterrows():
                        bbox2_coords = list(bbox2[['x', 'y', 'width', 'height']].values)
                        transformed_bbox2_coords = list(apply_shift_and_rotation(bbox2_coords, inverse_shift, rotation_angle, image_shape))

                        iou, rgb = compute_iou_and_rgb(bbox1_coords, transformed_bbox2_coords, bbox2_coords, image1_path, image2_path)
                        if iou > 0 and iou >= iou_threshold and rgb > 0.95:
                            writer.writerow([bbox1_coords[0], bbox1_coords[1], bbox1_coords[2], bbox1_coords[3], iou])
                            print("Case B",bbox1_coords, iou, rgb)

        # Standardfall: Vergleich mit Vorgänger (Case C) und Nachfolger (Case D)
        else:
            prev_file = csv_files[i - 1]
            next_file = csv_files[i + 1]

            prev_detections = pd.read_csv(os.path.join(detect_folder_path, prev_file))
            prev_detections = prev_detections[prev_detections['confidence'] >= confidence_threshold]

            next_detections = pd.read_csv(os.path.join(detect_folder_path, next_file))
            next_detections = next_detections[next_detections['confidence'] >= confidence_threshold]

            pair_key_prev = f"{prev_file.replace('_detections.csv', '').lower()}_{current_file.replace('_detections.csv', '').lower()}"
            if pair_key_prev in shift_results:
                shift_prev = shift_results[pair_key_prev]['shift']
                inverse_shift_prev = {'y': -shift_prev['y'], 'x': -shift_prev['x']}
                rotation_angle_prev = shift_results[pair_key_prev]['rotation_angle']
                #for rotated images
                #if rotation_angle_prev > 175 and rotation_angle_prev < 185:
                #    print("Rotated C: shift_prev",inverse_shift_prev)
                #    inverse_shift_prev = {'y': shift_prev['y'],'x': shift_prev['x']}
                #    print("Rotated C: inverse_shift_prev",inverse_shift_prev)

                print(f"\nProcessing Case C {current_file} -> {prev_file} with inverted shift: {inverse_shift_prev} and rotation: {rotation_angle_prev}°")

                image1_path = os.path.join(image_folder_path, current_file.replace('_detections.csv', ''))
                image2_path = os.path.join(image_folder_path, prev_file.replace('_detections.csv', ''))
                bbm_file = os.path.join(detect_folder_path, f"BBM_{current_file.replace('_detections.csv', '')}.csv")

                with open(bbm_file, 'a', newline='') as csvfile:
                    writer = csv.writer(csvfile)
                    if os.stat(bbm_file).st_size == 0:  # Kopfzeile nur schreiben, wenn Datei leer ist
                        writer.writerow(["x", "y", "width", "height", "IoU"])

                    for _, bbox1 in current_detections.iterrows():
                        bbox1_coords = tuple(bbox1[['x', 'y', 'width', 'height']].values)

                        for _, bbox2 in prev_detections.iterrows():
                            bbox2_coords = list(bbox2[['x', 'y', 'width', 'height']].values)
                            transformed_bbox2_coords = list(apply_shift_and_rotation(bbox2_coords, inverse_shift_prev, rotation_angle_prev, image_shape))

                            iou, rgb = compute_iou_and_rgb(bbox1_coords, transformed_bbox2_coords, bbox2_coords, image1_path, image2_path)

                            if iou > 0 and iou >= iou_threshold and rgb > 0.95:
                                if bbox1_coords not in processed_bboxes:  # Verhindert doppelte Einträge
                                    writer.writerow([*bbox1_coords, iou])
                                    processed_bboxes.add(bbox1_coords)  # Speicherung der Bounding Box
                                    print("Case C", bbox1_coords, iou, rgb)

            pair_key_next = f"{current_file.replace('_detections.csv', '').lower()}_{next_file.replace('_detections.csv', '').lower()}"
            if pair_key_next in shift_results:
                shift_next = shift_results[pair_key_next]['shift']
                rotation_angle_next = shift_results[pair_key_next]['rotation_angle']
                # for rotated images
                if rotation_angle_next > 175 and rotation_angle_next < 185:
                    #print("Rotated D: shift_next",shift_next)
                    shift_next = {'y': -shift_next['y'],'x': -shift_next['x']}
                    #print("Rotated D: shift_next",shift_next)

                print(f"\nProcessing Case D {current_file} -> {next_file} with shift: {shift_next} and rotation: {rotation_angle_next}°")

                image1_path = os.path.join(image_folder_path, current_file.replace('_detections.csv', ''))
                image2_path = os.path.join(image_folder_path, next_file.replace('_detections.csv', ''))

                with open(bbm_file, 'a', newline='') as csvfile:
                    writer = csv.writer(csvfile)

                    for _, bbox1 in current_detections.iterrows():
                        bbox1_coords = tuple(bbox1[['x', 'y', 'width', 'height']].values)

                        # **Check: Wurde bbox1 bereits in Case C gespeichert?**
                        if bbox1_coords in processed_bboxes:
                            continue  # Überspringe diese Bounding Box in Case D

                        for _, bbox2 in next_detections.iterrows():
                            bbox2_coords = list(bbox2[['x', 'y', 'width', 'height']].values)
                            transformed_bbox2_coords = list(apply_shift_and_rotation(bbox2_coords, shift_next, rotation_angle_next, image_shape))

                            iou, rgb = compute_iou_and_rgb(bbox1_coords, transformed_bbox2_coords, bbox2_coords, image1_path, image2_path)

                            if iou > 0 and iou >= iou_threshold and rgb > 0.95:
                                writer.writerow([*bbox1_coords, iou])
                                print("Case D", bbox1_coords, iou, rgb)

process_bounding_box_matching(
    detect_folder_path=detect_folder_path,
    image_folder_path=image_folder_path,
    shift_results=shift_results,
    iou_threshold=0.5,  # IoU-Schwellenwert
    confidence_threshold=0.5  # Vertrauensschwellenwert
)
# Out:
# shift_results {'dji_0613.jpg_dji_0614.jpg': {'shift': {'y': np.float32(683.79047), 'x': np.float32(-21.359924)}, 'rotation_angle': 0.0}, 'dji_0614.jpg_dji_0615.jpg': {'shift': {'y': np.float32(686.0), 'x': np.float32(-1.4401855)}, 'rotation_angle': 0.0}, 'dji_0615.jpg_dji_0616.jpg': {'shift': {'y': np.float32(711.6299), 'x': np.float32(-32.845703)}, 'rotation_angle': 0.0}, 'dji_0616.jpg_dji_0617.jpg': {'shift': {'y': np.float32(675.648), 'x': np.float32(-38.210327)}, 'rotation_angle': 0.0}, 'dji_0617.jpg_dji_0618.jpg': {'shift': {'y': np.float32(664.0), 'x': np.float32(-28.799805)}, 'rotation_angle': 0.0}, 'dji_0618.jpg_dji_0619.jpg': {'shift': {'y': np.float32(690.08545), 'x': np.float32(-10.36792)}, 'rotation_angle': 0.0}, 'dji_0619.jpg_dji_0620.jpg': {'shift': {'y': np.float32(686.4), 'x': np.float32(55.986816)}, 'rotation_angle': 0.0}, 'dji_0620.jpg_dji_0621.jpg': {'shift': {'y': np.float32(676.6849), 'x': np.float32(36.288025)}, 'rotation_angle': 0.0}, 'dji_0621.jpg_dji_0622.jpg': {'shift': {'y': np.float32(675.64795), 'x': np.float32(116.0)}, 'rotation_angle': 0.0}, 'dji_0622.jpg_dji_0623.jpg': {'shift': {'y': np.float32(659.90265), 'x': np.float32(23.887695)}, 'rotation_angle': 0.0}, 'dji_0623.jpg_dji_0624.jpg': {'shift': {'y': np.float32(660.0962), 'x': np.float32(60.47998)}, 'rotation_angle': 0.0}, 'dji_0624.jpg_dji_0625.jpg': {'shift': {'y': np.float32(608.2561), 'x': np.float32(65.691895)}, 'rotation_angle': 0.0}, 'dji_0625.jpg_dji_0626.jpg': {'shift': {'y': np.float64(-1734.9858838600762), 'x': np.float64(27.255336232512786)}, 'rotation_angle': -180.9}, 'dji_0626.jpg_dji_0627.jpg': {'shift': {'y': np.float32(630.72), 'x': np.float32(102.0105)}, 'rotation_angle': 0.40000000000000036}, 'dji_0627.jpg_dji_0628.jpg': {'shift': {'y': np.float32(651.5281), 'x': np.float32(87.09131)}, 'rotation_angle': 0.20000000000000018}, 'dji_0628.jpg_dji_0629.jpg': {'shift': {'y': np.float32(659.405), 'x': np.float32(39.414978)}, 'rotation_angle': 0.09999999999999964}, 'dji_0629.jpg_dji_0630.jpg': {'shift': {'y': np.float32(691.6536), 'x': np.float32(10.368042)}, 'rotation_angle': 0.0}, 'dji_0630.jpg_dji_0631.jpg': {'shift': {'y': np.float32(671.84644), 'x': np.float32(-8.0)}, 'rotation_angle': 0.10000000000000053}, 'dji_0631.jpg_dji_0632.jpg': {'shift': {'y': np.float32(710.9546), 'x': np.float32(-2.880005)}, 'rotation_angle': 0.0}, 'dji_0632.jpg_dji_0633.jpg': {'shift': {'y': np.float32(694.24146), 'x': np.float32(-4.0)}, 'rotation_angle': 0.0}, 'dji_0633.jpg_dji_0634.jpg': {'shift': {'y': np.float32(743.04004), 'x': np.float32(-21.599976)}, 'rotation_angle': 0.0}, 'dji_0634.jpg_dji_0635.jpg': {'shift': {'y': np.float32(712.11676), 'x': np.float32(-14.929932)}, 'rotation_angle': 0.0}, 'dji_0635.jpg_dji_0636.jpg': {'shift': {'y': np.float32(709.2001), 'x': np.float32(0.0)}, 'rotation_angle': 0.0}, 'dji_0636.jpg_dji_0637.jpg': {'shift': {'y': np.float32(732.96014), 'x': np.float32(-4.0561523)}, 'rotation_angle': 0.0}, 'dji_0637.jpg_dji_0638.jpg': {'shift': {'y': np.float32(734.40015), 'x': np.float32(-12.89978)}, 'rotation_angle': 0.0}, 'dji_0638.jpg_dji_0639.jpg': {'shift': {'y': np.float32(729.9537), 'x': np.float32(-2.985962)}, 'rotation_angle': 0.0}, 'dji_0639.jpg_dji_0640.jpg': {'shift': {'y': np.float32(758.0), 'x': np.float32(0.0)}, 'rotation_angle': 0.0}, 'dji_0640.jpg_dji_0641.jpg': {'shift': {'y': np.float32(711.2446), 'x': np.float32(-2.9858398)}, 'rotation_angle': 0.09999999999999964}, 'dji_0641.jpg_dji_0642.jpg': {'shift': {'y': np.float32(743.51025), 'x': np.float32(-7.0)}, 'rotation_angle': 0.0}, 'dji_0642.jpg_dji_0643.jpg': {'shift': {'y': np.float32(740.16003), 'x': np.float32(-12.0)}, 'rotation_angle': 0.0}, 'dji_0643.jpg_dji_0644.jpg': {'shift': {'y': np.float32(751.8401), 'x': np.float32(-4.147217)}, 'rotation_angle': 0.0}, 'dji_0644.jpg_dji_0645.jpg': {'shift': {'y': np.float32(748.5697), 'x': np.float32(1.7280273)}, 'rotation_angle': 0.0}, 'dji_0645.jpg_dji_0646.jpg': {'shift': {'y': np.float32(761.7588), 'x': np. ...
# pair_key dji_0613.jpg_dji_0614.jpg
#
# Processing Case A DJI_0613.JPG_detections.csv -> DJI_0614.JPG_detections.csv with shift: {'y': np.float32(683.79047), 'x': np.float32(-21.359924)} and rotation: 0.0°
#
# Processing Case C DJI_0614.JPG_detections.csv -> DJI_0613.JPG_detections.csv with inverted shift: {'y': np.float32(-683.79047), 'x': np.float32(21.359924)} and rotation: 0.0°
#
# Processing Case D DJI_0614.JPG_detections.csv -> DJI_0615.JPG_detections.csv with shift: {'y': np.float32(686.0), 'x': np.float32(-1.4401855)} and rotation: 0.0°
# Case D (2637, 1000, 265, 131) 0.66 0.9795578213475834
# Case D (2894, 116, 265, 119) 0.57 0.9974135310076226
# Case D (2898, 230, 290, 142) 0.56 0.9772728659998106
#
# Processing Case C DJI_0615.JPG_detections.csv -> DJI_0614.JPG_detections.csv with inverted shift: {'y': np.float32(-686.0), 'x': np.float32(1.4401855)} and rotation: 0.0°
# Case C (2637, 1712, 265, 131) 0.66 0.9795578213475834
# Case C (2898, 832, 256, 114) 0.57 0.9974135310076226
# Case C (2898, 951, 273, 125) 0.56 0.9772728659998106
#
# Processing Case D DJI_0615.JPG_detections.csv -> DJI_0616.JPG_detections.csv with shift: {'y': np.float32(711.6299), 'x': np.float32(-32.845703)} and rotation: 0.0°
# Case D (1748, 139, 282, 199) 0.59 0.9947105504434746
# Case D (3582, 1410, 188, 108) 0.83 0.988939127511298
# Case D (3001, 316, 273, 153) 0.78 0.9726203202863025
# Case D (5258, 339, 205, 119) 0.56 0.9829902305118647
# Case D (1812, 1818, 222, 114) 0.68 0.9726979371368835
# Case D (4480, 105, 205, 119) 0.82 0.9700231946257973
# Case D (2261, 299, 145, 233) 0.6 0.9860631063963522
# Case D (3022, 119, 111, 193) 0.76 0.9956773024220822
#
# Processing Case C DJI_0616.JPG_detections.csv -> DJI_0615.JPG_detections.csv with inverted shift: {'y': np.float32(-711.6299), 'x': np.float32(32.845703)} and rotation: 0.0°
# Case C (1731, 892, 282, 188) 0.59 0.9947105504434746
# Case C (2244, 1048, 145, 239) 0.6 0.9860631063963522
# Case C (2607, 2431, 273, 131) 0.87 0.9747545562204112
# Case C (2992, 849, 102, 182) 0.76 0.9956773024220822
# Case C (5194, 1034, 196, 108) 0.56 0.9829902305118647
# Case C (2966, 1045, 273, 153) 0.78 0.9726203202863025
# Case C (2868, 1558, 247, 119) 0.76 0.9924504781573467
# Case C (1782, 2550, 230, 119) 0.68 0.9726979371368835
# Case C (4428, 817, 205, 119) 0.82 0.9700231946257973
# Case C (3543, 2123, 179, 96) 0.83 0.988939127511298
# Case C (2877, 1675, 265, 125) 0.76 0.9907818086864487
#
# Processing Case D DJI_0616.JPG_detections.csv -> DJI_0617.JPG_detections.csv with shift: {'y': np.float32(675.648), 'x': np.float32(-38.210327)} and rotation: 0.0°
# Case D (5112, 515, 102, 210) 0.55 0.9860547316920735
# Case D (3603, 37, 213, 74) 0.55 0.9678001400553985
#
# Processing Case C DJI_0617.JPG_detections.csv -> DJI_0616.JPG_detections.csv with inverted shift: {'y': np.float32(-675.648), 'x': np.float32(38.210327)} and rotation: 0.0°
# Case C (1705, 1607, 282, 193) 0.61 0.9851596524418136
# Case C (2218, 1752, 145, 245) 0.68 0.9886042543566929
# Case C (2941, 1738, 273, 159) 0.73 0.9819041875550639
# Case C (5138, 1687, 188, 114) 0.57 0.9944121376132197
# Case C (2842, 2371, 265, 125) 0.71 0.9821355583970954
# Case C (1761, 3249, 222, 114) 0.59 0.9717386785388563
# Case C (2834, 2245, 247, 125) 0.8 0.9946745052743884
# Case C (3569, 703, 213, 131) 0.55 0.9678001400553985
# Case C (4386, 1487, 205, 114) 0.88 0.9873845749360232
# Case C (2962, 1547, 111, 188) 0.68 0.9816386432077026
# Case C (5057, 1197, 94, 159) 0.55 0.9860547316920735
# Case C (2582, 3109, 256, 142) 0.84 0.981809066367168
#
# Processing Case D DJI_0617.JPG_detections.csv -> DJI_0618.JPG_detections.csv with shift: {'y': np.float32(664.0), 'x': np.float32(-28.799805)} and rotation: 0.0°
# Case D (3885, 584, 230, 176) 0.71 0.9677601209289243
#
# Processing Case C DJI_0618.JPG_detections.csv -> DJI_0617.JPG_detections.csv with inverted shift: {'y': np.float32(-664.0), 'x': np.float32(28.799805)} and rotation: 0.0°
# Case C (1697, 2319, 282, 205) 0.54 0.9743835843066455
# Case C (2201, 2453, 145, 245) 0.64 0.99451558596771
# Case C (3864, 1273, 222, 176) 0.71 0.9677601209289243
# Case C (3548, 1390, 205, 136) 0.66 0.9824577283474033
# Case C (5095, 2331, 188, 114) 0.62 0.9871069201272598
# Case C (2817, 2926, 265, 131) 0.7 0.9886786967787067
# Case C (4351, 2146, 205, 119) 0.87 0.950364488799815
# Case C (2924, 2428, 256, 159) 0.67 0.9920887054059859
# Case C (2945, 2225, 111, 188) 0.71 0.983131549596334
#
# Processing Case D DJI_0618.JPG_detections.csv -> DJI_0619.JPG_detections.csv with shift: {'y': np.float32(690.08545), 'x': np.float32(-10.36792)} and rotation: 0.0°
# Case D (2817, 424, 230, 153) 0.74 0.992330975829423
# Case D (2235, 772, 179, 119) 0.6 0.9599649585659266
#
# Processing Case C DJI_0619.JPG_detections.csv -> DJI_0618.JPG_detections.csv with inverted shift: {'y': np.float32(-690.08545), 'x': np.float32(10.36792)} and rotation: 0.0°
# Case C (1692, 3038, 273, 205) 0.73 0.9788007170015066
# Case C (3843, 1949, 213, 171) 0.78 0.9854238443233878
# Case C (2188, 3146, 136, 239) 0.91 0.9875609754599893
# Case C (2800, 1131, 213, 142) 0.74 0.992330975829423
# Case C (3531, 2069, 205, 136) 0.8 0.9959859786804819
# Case C (2218, 1487, 162, 114) 0.6 0.9599649585659266
# Case C (2911, 3106, 265, 171) 0.84 0.9928087422638057
# Case C (2932, 2909, 102, 188) 0.86 0.9936988617809067
# Case C (2795, 3591, 256, 114) 0.61 0.9923040607340526
#
# Processing Case D DJI_0619.JPG_detections.csv -> DJI_0620.JPG_detections.csv with shift: {'y': np.float32(686.4), 'x': np.float32(55.986816)} and rotation: 0.0°
# Case D (3266, 1048, 256, 159) 0.73 0.9805266500021367
# Case D (4433, 524, 213, 148) 0.66 0.9694796586869745
#
# Processing Case C DJI_0620.JPG_detections.csv -> DJI_0619.JPG_detections.csv with inverted shift: {'y': np.float32(-686.4), 'x': np.float32(-55.986816)} and rotation: 0.0°
# Case C (3304, 1749, 247, 159) 0.73 0.9805266500021367
# Case C (2855, 1832, 222, 142) 0.78 0.9871716769866616
# Case C (3582, 2744, 205, 142) 0.81 0.9606286672935245
# Case C (2983, 3571, 102, 153) 0.69 0.9881265093590333
# Case C (4467, 1194, 213, 142) 0.66 0.9694796586869745
#
# Processing Case D DJI_0620.JPG_detections.csv -> DJI_0621.JPG_detections.csv with shift: {'y': np.float32(676.6849), 'x': np.float32(36.288025)} and rotation: 0.0°
# Case D (3894, 2624, 213, 188) 0.83 0.9717709734898718
#
# Processing Case C DJI_0621.JPG_detections.csv -> DJI_0620.JPG_detections.csv with inverted shift: {'y': np.float32(-676.6849), 'x': np.float32(-36.288025)} and rotation: 0.0°
# Case C (3338, 2425, 230, 165) 0.9 0.9892733199297962
# Case C (3612, 3405, 213, 153) 0.76 0.9774824642736825
# Case C (3924, 3288, 222, 205) 0.83 0.9717709734898718
# Case C (4505, 1849, 222, 142) 0.71 0.9941592246717345
#
# Processing Case D DJI_0621.JPG_detections.csv -> DJI_0622.JPG_detections.csv with shift: {'y': np.float32(675.64795), 'x': np.float32(116.0)} and rotation: 0.0°
#
# Processing Case C DJI_0622.JPG_detections.csv -> DJI_0621.JPG_detections.csv with inverted shift: {'y': np.float32(-675.64795), 'x': np.float32(-116.0)} and rotation: 0.0°
# Case C (3441, 3120, 230, 165) 0.71 0.9929316638087567
# Case C (4634, 2510, 205, 142) 0.73 0.9966489945607512
#
# Processing Case D DJI_0622.JPG_detections.csv -> DJI_0623.JPG_detections.csv with shift: {'y': np.float32(659.90265), 'x': np.float32(23.887695)} and rotation: 0.0°
#
# Processing Case C DJI_0623.JPG_detections.csv -> DJI_0622.JPG_detections.csv with inverted shift: {'y': np.float32(-659.90265), 'x': np.float32(-23.887695)} and rotation: 0.0°
# Case C (4664, 3166, 213, 142) 0.89 0.9982209376721204
#
# Processing Case D DJI_0623.JPG_detections.csv -> DJI_0624.JPG_detections.csv with shift: {'y': np.float32(660.0962), 'x': np.float32(60.47998)} and rotation: 0.0°
#
# Processing Case C DJI_0624.JPG_detections.csv -> DJI_0623.JPG_detections.csv with inverted shift: {'y': np.float32(-660.0962), 'x': np.float32(-60.47998)} and rotation: 0.0°
#
# Processing Case D DJI_0624.JPG_detections.csv -> DJI_0625.JPG_detections.csv with shift: {'y': np.float32(608.2561), 'x': np.float32(65.691895)} and rotation: 0.0°
# Case D (4894, 598, 145, 171) 0.86 0.9981556335120245
# Case D (5249, 102, 136, 205) 0.8 0.9940003066540342
# Case D (2376, 795, 119, 233) 0.64 0.9912390156122666
# Case D (2975, 621, 136, 250) 0.66 0.995232801050931
# Case D (4873, 379, 119, 233) 0.84 0.984700921209442
# Case D (4997, 213, 111, 210) 0.88 0.9924669146002922
# Case D (2235, 763, 111, 228) 0.56 0.989231891733951
# Case D (4967, 433, 102, 216) 0.81 0.9962311263285756
# Case D (1714, 703, 111, 290) 0.59 0.9789885240110617
#
# Processing Case C DJI_0625.JPG_detections.csv -> DJI_0624.JPG_detections.csv with inverted shift: {'y': np.float32(-608.2561), 'x': np.float32(-65.691895)} and rotation: 0.0°
# Case C (2445, 1450, 119, 233) 0.64 0.9912390156122666
# Case C (5309, 695, 136, 228) 0.8 0.9940003066540342
# Case C (5061, 826, 102, 205) 0.88 0.9924669146002922
# Case C (4954, 1208, 145, 159) 0.86 0.9981556335120245
# Case C (3035, 1271, 136, 239) 0.66 0.995232801050931
# Case C (4929, 986, 128, 228) 0.84 0.984700921209442
# Case C (2299, 1427, 102, 222) 0.56 0.989231891733951
# Case C (5023, 1040, 111, 210) 0.81 0.9962311263285756
# Case C (1786, 1373, 102, 296) 0.59 0.9789885240110617
#
# Processing Case D DJI_0625.JPG_detections.csv -> DJI_0626.JPG_detections.csv with shift: {'y': np.float64(-1734.9858838600762), 'x': np.float64(27.255336232512786)} and rotation: -180.9°
#
# Processing Case C DJI_0626.JPG_detections.csv -> DJI_0625.JPG_detections.csv with inverted shift: {'y': np.float64(1734.9858838600762), 'x': np.float64(-27.255336232512786)} and rotation: -180.9°
#
# Processing Case D DJI_0626.JPG_detections.csv -> DJI_0627.JPG_detections.csv with shift: {'y': np.float32(630.72), 'x': np.float32(102.0105)} and rotation: 0.40000000000000036°
# Case D (1145, 2143, 153, 182) 0.88 0.9928057978214453
# Case D (1235, 2738, 282, 245) 0.82 0.9874338503152839
# Case D (1068, 2308, 102, 216) 0.75 0.9646844094865362
# Case D (508, 2331, 111, 216) 0.6 0.9940394515855917
# Case D (743, 2656, 153, 228) 0.65 0.9915770687489537
# Case D (1175, 2371, 128, 239) 0.85 0.9929025173864527
# Case D (1197, 2978, 188, 85) 0.66 0.9591673353535008
# Case D (3779, 2037, 102, 222) 0.59 0.9522389528957448
# Case D (3189, 2197, 119, 245) 0.78 0.9933175436746695
# Case D (1021, 2533, 94, 222) 0.65 0.991659375943522
# Case D (756, 2362, 111, 210) 0.63 0.9934242936228559
# Case D (4420, 2131, 102, 262) 0.64 0.9961161718299542
# Case D (521, 2596, 136, 233) 0.56 0.9815109300242941
# Case D (3920, 2063, 111, 216) 0.58 0.9508151982466916
#
# Processing Case C DJI_0627.JPG_detections.csv -> DJI_0626.JPG_detections.csv with inverted shift: {'y': np.float32(-630.72), 'x': np.float32(-102.0105)} and rotation: 0.40000000000000036°
# Case C (1359, 3365, 290, 256) 0.82 0.9874338503152839
# Case C (1256, 2775, 153, 182) 0.88 0.9928057978214453
# Case C (1184, 2941, 111, 216) 0.75 0.9646844094865362
# Case C (872, 3297, 153, 233) 0.65 0.9915770687489537
# Case C (1286, 3001, 128, 245) 0.85 0.9929025173864527
# Case C (1141, 3166, 94, 210) 0.65 0.991659375943522
# Case C (3885, 2616, 94, 228) 0.59 0.9522389528957448
# Case C (876, 3009, 111, 205) 0.63 0.9934242936228559
# Case C (632, 2978, 119, 210) 0.6 0.9940394515855917
# Case C (1325, 3602, 188, 91) 0.66 0.9591673353535008
# Case C (658, 3234, 136, 233) 0.56 0.9815109300242941
# Case C (4531, 2721, 102, 302) 0.64 0.9961161718299542
# Case C (4027, 2644, 102, 216) 0.58 0.9508151982466916
# Case C (3296, 2812, 128, 290) 0.78 0.9933175436746695
#
# Processing Case D DJI_0627.JPG_detections.csv -> DJI_0628.JPG_detections.csv with shift: {'y': np.float32(651.5281), 'x': np.float32(87.09131)} and rotation: 0.20000000000000018°
# Case D (4860, 2331, 128, 205) 0.7 0.9914628561780213
#
# Processing Case C DJI_0628.JPG_detections.csv -> DJI_0627.JPG_detections.csv with inverted shift: {'y': np.float32(-651.5281), 'x': np.float32(-87.09131)} and rotation: 0.20000000000000018°
# Case C (1359, 3420, 153, 171) 0.76 0.9659429701103365
# Case C (4634, 3337, 102, 290) 0.59 0.9629832626342765
# Case C (4959, 2964, 119, 205) 0.7 0.9914628561780213
# Case C (3381, 3417, 128, 233) 0.68 0.9809194895689812
#
# Processing Case D DJI_0628.JPG_detections.csv -> DJI_0629.JPG_detections.csv with shift: {'y': np.float32(659.405), 'x': np.float32(39.414978)} and rotation: 0.09999999999999964°
# Case D (1449, 59, 213, 119) 0.65 0.9811823410910521
#
# Processing Case C DJI_0629.JPG_detections.csv -> DJI_0628.JPG_detections.csv with inverted shift: {'y': np.float32(-659.405), 'x': np.float32(-39.414978)} and rotation: 0.09999999999999964°
# Case C (1491, 743, 230, 165) 0.65 0.9811823410910521
#
# Processing Case D DJI_0629.JPG_detections.csv -> DJI_0630.JPG_detections.csv with shift: {'y': np.float32(691.6536), 'x': np.float32(10.368042)} and rotation: 0.0°
# Case D (2924, 85, 239, 171) 0.62 0.9876591480718584
#
# Processing Case C DJI_0630.JPG_detections.csv -> DJI_0629.JPG_detections.csv with inverted shift: {'y': np.float32(-691.6536), 'x': np.float32(-10.368042)} and rotation: 0.0°
# Case C (2928, 815, 247, 182) 0.62 0.9876591480718584
# Case C (1496, 1462, 222, 153) 0.68 0.9908160898440129
#
# Processing Case D DJI_0630.JPG_detections.csv -> DJI_0631.JPG_detections.csv with shift: {'y': np.float32(671.84644), 'x': np.float32(-8.0)} and rotation: 0.10000000000000053°
# Case D (3402, 723, 222, 159) 0.64 0.9619768017842416
#
# Processing Case C DJI_0631.JPG_detections.csv -> DJI_0630.JPG_detections.csv with inverted shift: {'y': np.float32(-671.84644), 'x': np.float32(8.0)} and rotation: 0.10000000000000053°
# Case C (2919, 1519, 247, 176) 0.69 0.9859688068305767
# Case C (3394, 1430, 222, 159) 0.64 0.9619768017842416
# Case C (1487, 2146, 222, 165) 0.85 0.9931151009945065
#
# Processing Case D DJI_0631.JPG_detections.csv -> DJI_0632.JPG_detections.csv with shift: {'y': np.float32(710.9546), 'x': np.float32(-2.880005)} and rotation: 0.0°
# Case D (2603, 427, 213, 159) 0.57 0.9845761201219927
# Case D (2270, 552, 282, 205) 0.61 0.9870516649437011
# Case D (196, 1621, 153, 176) 0.56 0.9881687219272774
# Case D (786, 128, 119, 233) 0.52 0.9725185020240852
#
# Processing Case C DJI_0632.JPG_detections.csv -> DJI_0631.JPG_detections.csv with inverted shift: {'y': np.float32(-710.9546), 'x': np.float32(2.880005)} and rotation: 0.0°
# Case C (2911, 2257, 230, 171) 0.69 0.9632496882247525
# Case C (2603, 1179, 213, 148) 0.57 0.9845761201219927
# Case C (2274, 1308, 273, 199) 0.61 0.9870516649437011
# Case C (3385, 2168, 222, 153) 0.67 0.9875310081692918
# Case C (1487, 2869, 239, 153) 0.8 0.9916459796076735
# Case C (213, 2362, 153, 176) 0.56 0.9881687219272774
# Case C (795, 892, 119, 210) 0.52 0.9725185020240852
#
# Processing Case D DJI_0632.JPG_detections.csv -> DJI_0633.JPG_detections.csv with shift: {'y': np.float32(694.24146), 'x': np.float32(-4.0)} and rotation: 0.0°
# Case D (324, 2225, 205, 233) 0.71 0.9903968449657213
# Case D (4587, 199, 316, 228) 0.62 0.9676767229044126
# Case D (3266, 279, 102, 205) 0.69 0.980784405647784
# Case D (769, 108, 222, 136) 0.75 0.9928026956695566
# Case D (1675, 336, 222, 125) 0.69 0.9919625106841575
# Case D (4069, 94, 153, 188) 0.67 0.9743458868952724
# Case D (3296, 79, 299, 159) 0.79 0.9609215513740499
# Case D (3997, 1798, 179, 131) 0.71 0.9541627916120919
# Case D (889, 681, 119, 222) 0.61 0.970979158294126
#
# Processing Case C DJI_0633.JPG_detections.csv -> DJI_0632.JPG_detections.csv with inverted shift: {'y': np.float32(-694.24146), 'x': np.float32(4.0)} and rotation: 0.0°
# Case C (4569, 937, 299, 210) 0.62 0.9676767229044126
# Case C (3300, 789, 290, 188) 0.79 0.9609215513740499
# Case C (773, 817, 230, 131) 0.75 0.9928026956695566
# Case C (2278, 2017, 282, 193) 0.82 0.9940916815420163
# Case C (1675, 1051, 222, 119) 0.69 0.9919625106841575
# Case C (4056, 783, 145, 256) 0.67 0.9743458868952724
# Case C (342, 2935, 205, 228) 0.71 0.9903968449657213
# Case C (2603, 1886, 213, 148) 0.81 0.9902353500982312
# Case C (2898, 2955, 239, 176) 0.89 0.9867343365280165
# Case C (3372, 2864, 230, 153) 0.9 0.9887721781982479
# Case C (3261, 1003, 111, 193) 0.69 0.980784405647784
# Case C (209, 3040, 145, 176) 0.79 0.9907474268846999
# Case C (799, 1573, 111, 216) 0.77 0.9830035776984526
# Case C (3984, 2508, 171, 125) 0.71 0.9541627916120919
# Case C (884, 1362, 94, 171) 0.61 0.970979158294126
#
# Processing Case D DJI_0633.JPG_detections.csv -> DJI_0634.JPG_detections.csv with shift: {'y': np.float32(743.04004), 'x': np.float32(-21.599976)} and rotation: 0.0°
#
# Processing Case C DJI_0634.JPG_detections.csv -> DJI_0633.JPG_detections.csv with inverted shift: {'y': np.float32(-743.04004), 'x': np.float32(21.599976)} and rotation: 0.0°
# Case C (4531, 1715, 290, 205) 0.65 0.9696075038386276
# Case C (3266, 1564, 290, 176) 0.65 0.9837160615154075
# Case C (2252, 2764, 282, 182) 0.91 0.9635012235604115
# Case C (4022, 1558, 145, 245) 0.66 0.9888626101960962
# Case C (1658, 1806, 222, 114) 0.78 0.9963892399757474
# Case C (2573, 2633, 222, 136) 0.85 0.9682589402341847
# Case C (3338, 3585, 213, 125) 0.65 0.9558722504271678
# Case C (3231, 1764, 102, 188) 0.72 0.9956218226990335
#
# Processing Case D DJI_0634.JPG_detections.csv -> DJI_0635.JPG_detections.csv with shift: {'y': np.float32(712.11676), 'x': np.float32(-14.929932)} and rotation: 0.0°
# Case D (3385, 1031, 273, 136) 0.7 0.9645170933118126
# Case D (756, 1573, 230, 125) 0.88 0.9606464829641693
# Case D (2667, 407, 205, 108) 0.56 0.9702267045999441
# Case D (778, 2314, 119, 216) 0.8 0.9902359239396479
# Case D (974, 2114, 102, 205) 0.79 0.9790356896909755
# Case D (872, 2126, 102, 216) 0.85 0.9773464400871931
# Case D (3385, 897, 290, 142) 0.64 0.9577981463243574
#
# Processing Case C DJI_0635.JPG_detections.csv -> DJI_0634.JPG_detections.csv with inverted shift: {'y': np.float32(-712.11676), 'x': np.float32(14.929932)} and rotation: 0.0°
# Case C (3364, 1764, 265, 131) 0.7 0.9645170933118126
# Case C (2231, 3468, 273, 176) 0.88 0.9895499046784786
# Case C (4493, 2442, 282, 188) 0.74 0.9501761790051722
# Case C (748, 2282, 213, 119) 0.88 0.9606464829641693
# Case C (2547, 3334, 222, 136) 0.77 0.9858624946087043
# Case C (3244, 2282, 282, 165) 0.89 0.9857240242289835
# Case C (3992, 2282, 136, 233) 0.74 0.9606784598128332
# Case C (1641, 2516, 222, 119) 0.94 0.9974805324567253
# Case C (3201, 2479, 111, 182) 0.73 0.9716132649353643
# Case C (2654, 1148, 196, 108) 0.56 0.9702267045999441
# Case C (859, 2830, 111, 222) 0.85 0.9773464400871931
# Case C (765, 3009, 111, 216) 0.8 0.9902359239396479
# Case C (966, 2815, 102, 205) 0.79 0.9790356896909755
# Case C (3372, 1638, 282, 131) 0.64 0.9577981463243574
#
# Processing Case D DJI_0635.JPG_detections.csv -> DJI_0636.JPG_detections.csv with shift: {'y': np.float32(709.2001), 'x': np.float32(0.0)} and rotation: 0.0°
# Case D (3667, 857, 273, 131) 0.63 0.9958035894955218
# Case D (923, 1271, 444, 182) 0.82 0.9737379414792783
# Case D (4266, 795, 256, 142) 0.56 0.9765500425656685
#
# Processing Case C DJI_0636.JPG_detections.csv -> DJI_0635.JPG_detections.csv with inverted shift: {'y': np.float32(-709.2001), 'x': np.float32(-0.0)} and rotation: 0.0°
# Case C (3236, 2986, 282, 159) 0.89 0.9510693352085687
# Case C (4475, 3152, 282, 193) 0.86 0.9501966692558801
# Case C (1641, 3211, 222, 119) 0.79 0.9716217985343136
# Case C (752, 2978, 222, 119) 0.77 0.9702840000889137
# Case C (3655, 1590, 247, 125) 0.63 0.9958035894955218
# Case C (3368, 2365, 273, 125) 0.73 0.9815856746358009
# Case C (3197, 3180, 102, 182) 0.84 0.9700441049309599
# Case C (3347, 2482, 265, 108) 0.73 0.9539513301323594
# Case C (4253, 1536, 247, 119) 0.56 0.9765500425656685
# Case C (867, 3519, 111, 222) 0.73 0.9905902773273381
# Case C (974, 3502, 119, 210) 0.7 0.967329424027711
# Case C (2654, 1875, 196, 102) 0.71 0.9608572265828565
# Case C (931, 1995, 444, 171) 0.82 0.9737379414792783
#
# Processing Case D DJI_0636.JPG_detections.csv -> DJI_0637.JPG_detections.csv with shift: {'y': np.float32(732.96014), 'x': np.float32(-4.0561523)} and rotation: 0.0°
# Case D (4501, 1504, 230, 102) 0.77 0.9718913858854799
#
# Processing Case C DJI_0637.JPG_detections.csv -> DJI_0636.JPG_detections.csv with inverted shift: {'y': np.float32(-732.96014), 'x': np.float32(4.0561523)} and rotation: 0.0°
# Case C (3638, 2334, 247, 119) 0.76 0.9944392042451223
# Case C (3338, 3211, 247, 108) 0.87 0.9660778831416421
# Case C (4484, 2245, 230, 102) 0.77 0.9718913858854799
# Case C (3347, 3095, 282, 136) 0.82 0.9651388316854633
#
# Processing Case D DJI_0637.JPG_detections.csv -> DJI_0638.JPG_detections.csv with shift: {'y': np.float32(734.40015), 'x': np.float32(-12.89978)} and rotation: 0.0°
# Case D (2646, 2607, 196, 108) 0.84 0.959511115141879
#
# Processing Case C DJI_0638.JPG_detections.csv -> DJI_0637.JPG_detections.csv with inverted shift: {'y': np.float32(-734.40015), 'x': np.float32(12.89978)} and rotation: 0.0°
# Case C (3620, 3069, 247, 119) 0.95 0.9760834450630873
# Case C (2633, 3334, 188, 114) 0.84 0.959511115141879
# Case C (4454, 2989, 239, 96) 0.72 0.9578524852465794
#
# Processing Case D DJI_0638.JPG_detections.csv -> DJI_0639.JPG_detections.csv with shift: {'y': np.float32(729.9537), 'x': np.float32(-2.985962)} and rotation: 0.0°
# Case D (5348, 1892, 179, 102) 0.81 0.9696330259714041
#
# Processing Case C DJI_0639.JPG_detections.csv -> DJI_0638.JPG_detections.csv with inverted shift: {'y': np.float32(-729.9537), 'x': np.float32(2.985962)} and rotation: 0.0°
# Case C (5326, 2622, 188, 102) 0.81 0.9696330259714041
#
# Processing Case D DJI_0639.JPG_detections.csv -> DJI_0640.JPG_detections.csv with shift: {'y': np.float32(758.0), 'x': np.float32(0.0)} and rotation: 0.0°
# Case D (5326, 2479, 239, 136) 0.77 0.9654787044643068
#
# Processing Case C DJI_0640.JPG_detections.csv -> DJI_0639.JPG_detections.csv with inverted shift: {'y': np.float32(-758.0), 'x': np.float32(-0.0)} and rotation: 0.0°
# Case C (5309, 3229, 222, 131) 0.77 0.9654787044643068
# Case C (5296, 3365, 179, 108) 0.56 0.9528810401484682
#
# Processing Case D DJI_0640.JPG_detections.csv -> DJI_0641.JPG_detections.csv with shift: {'y': np.float32(711.2446), 'x': np.float32(-2.9858398)} and rotation: 0.09999999999999964°
#
# Processing Case C DJI_0641.JPG_detections.csv -> DJI_0640.JPG_detections.csv with inverted shift: {'y': np.float32(-711.2446), 'x': np.float32(2.9858398)} and rotation: 0.09999999999999964°
#
# Processing Case D DJI_0641.JPG_detections.csv -> DJI_0642.JPG_detections.csv with shift: {'y': np.float32(743.51025), 'x': np.float32(-7.0)} and rotation: 0.0°
# Case D (675, 59, 239, 119) 0.52 0.9843238661978586
# Case D (2774, 108, 111, 216) 0.82 0.9934325702239223
#
# Processing Case C DJI_0642.JPG_detections.csv -> DJI_0641.JPG_detections.csv with inverted shift: {'y': np.float32(-743.51025), 'x': np.float32(7.0)} and rotation: 0.0°
# Case C (688, 832, 247, 114) 0.52 0.9843238661978586
# Case C (2765, 869, 111, 210) 0.82 0.9934325702239223
#
# Processing Case D DJI_0642.JPG_detections.csv -> DJI_0643.JPG_detections.csv with shift: {'y': np.float32(740.16003), 'x': np.float32(-12.0)} and rotation: 0.0°
# Case D (307, 151, 171, 279) 0.6 0.9587199130598879
# Case D (179, 182, 136, 262) 0.61 0.9725857926171316
#
# Processing Case C DJI_0643.JPG_detections.csv -> DJI_0642.JPG_detections.csv with inverted shift: {'y': np.float32(-740.16003), 'x': np.float32(12.0)} and rotation: 0.0°
# Case C (316, 931, 171, 267) 0.6 0.9587199130598879
# Case C (183, 957, 128, 250) 0.61 0.9725857926171316
#
# Processing Case D DJI_0643.JPG_detections.csv -> DJI_0644.JPG_detections.csv with shift: {'y': np.float32(751.8401), 'x': np.float32(-4.147217)} and rotation: 0.0°
# Case D (5262, 1690, 230, 131) 0.86 0.9880318140607721
# Case D (530, 880, 119, 188) 0.76 0.9691184484596028
# Case D (5232, 1436, 307, 136) 0.9 0.9724815257539805
# Case D (684, 1596, 239, 102) 0.86 0.9766122477672268
# Case D (2753, 1635, 102, 193) 0.86 0.9710462558656807
#
# Processing Case C DJI_0644.JPG_detections.csv -> DJI_0643.JPG_detections.csv with inverted shift: {'y': np.float32(-751.8401), 'x': np.float32(4.147217)} and rotation: 0.0°
# Case C (5245, 2439, 230, 125) 0.86 0.9880318140607721
# Case C (5219, 2191, 299, 131) 0.9 0.9724815257539805
# Case C (534, 1644, 111, 176) 0.76 0.9691184484596028
# Case C (324, 1692, 153, 250) 0.8 0.9524750458686421
# Case C (692, 2345, 239, 108) 0.86 0.9766122477672268
# Case C (196, 1712, 119, 233) 0.71 0.9902430462375093
# Case C (2744, 2382, 102, 182) 0.86 0.9710462558656807
#
# Processing Case D DJI_0644.JPG_detections.csv -> DJI_0645.JPG_detections.csv with shift: {'y': np.float32(748.5697), 'x': np.float32(1.7280273)} and rotation: 0.0°
# Case D (2483, 190, 230, 108) 0.69 0.9517940957466144
#
# Processing Case C DJI_0645.JPG_detections.csv -> DJI_0644.JPG_detections.csv with inverted shift: {'y': np.float32(-748.5697), 'x': np.float32(-1.7280273)} and rotation: 0.0°
# Case C (346, 2433, 145, 239) 0.72 0.9698775346804581
# Case C (2483, 957, 230, 102) 0.69 0.9517940957466144
# Case C (5211, 2935, 299, 136) 0.88 0.9749748798636648
# Case C (696, 3078, 230, 114) 0.73 0.9763493784037762
# Case C (547, 2382, 119, 171) 0.74 0.9776021289229807
# Case C (209, 2451, 111, 228) 0.76 0.9746726591253554
#
# Processing Case D DJI_0645.JPG_detections.csv -> DJI_0646.JPG_detections.csv with shift: {'y': np.float32(761.7588), 'x': np.float32(-1.1999512)} and rotation: 0.0°
# Case D (3864, 874, 222, 108) 0.73 0.9765227848587197
# Case D (5407, 763, 128, 136) 0.58 0.9613561504282683
#
# Processing Case C DJI_0646.JPG_detections.csv -> DJI_0645.JPG_detections.csv with inverted shift: {'y': np.float32(-761.7588), 'x': np.float32(1.1999512)} and rotation: 0.0°
# Case C (350, 3174, 153, 239) 0.79 0.9869938436508061
# Case C (3860, 1650, 230, 96) 0.73 0.9765227848587197
# Case C (2479, 1729, 222, 96) 0.79 0.9889816299299651
# Case C (555, 3120, 119, 176) 0.66 0.9932295434841076
# Case C (209, 3180, 111, 228) 0.73 0.961025447920487
# Case C (5399, 1553, 145, 119) 0.58 0.9613561504282683
#
# Processing Case D DJI_0646.JPG_detections.csv -> DJI_0647.JPG_detections.csv with shift: {'y': np.float32(756.86426), 'x': np.float32(-15.599976)} and rotation: 0.0°
#
# Processing Case C DJI_0647.JPG_detections.csv -> DJI_0646.JPG_detections.csv with inverted shift: {'y': np.float32(-756.86426), 'x': np.float32(15.599976)} and rotation: 0.0°
# Case C (3834, 2413, 230, 96) 0.81 0.9743557660569249
# Case C (2466, 2482, 213, 85) 0.85 0.9749752758023712
#
# Processing Case D DJI_0647.JPG_detections.csv -> DJI_0648.JPG_detections.csv with shift: {'y': np.float32(751.84), 'x': np.float32(-29.0)} and rotation: 0.0°
# Case D (1949, 353, 222, 114) 0.54 0.9852518307917743
# Case D (5386, 2319, 171, 114) 0.72 0.9829971993589754
#
# Processing Case C DJI_0648.JPG_detections.csv -> DJI_0647.JPG_detections.csv with inverted shift: {'y': np.float32(-751.84), 'x': np.float32(29.0)} and rotation: 0.0°
# Case C (3800, 3157, 230, 102) 0.82 0.9554748179681692
# Case C (2436, 3226, 222, 91) 0.8 0.9900163832409822
# Case C (5360, 3075, 222, 119) 0.72 0.9829971993589754
# Case C (1923, 1137, 222, 108) 0.54 0.9852518307917743
#
# Processing Case D DJI_0648.JPG_detections.csv -> DJI_0649.JPG_detections.csv with shift: {'y': np.float32(775.6794), 'x': np.float32(-10.079895)} and rotation: 0.0°
#
# Processing Case C DJI_0649.JPG_detections.csv -> DJI_0648.JPG_detections.csv with inverted shift: {'y': np.float32(-775.6794), 'x': np.float32(10.079895)} and rotation: 0.0°
#
# Processing Case D DJI_0649.JPG_detections.csv -> DJI_0650.JPG_detections.csv with shift: {'y': np.float32(806.0), 'x': np.float32(-3.4560547)} and rotation: 0.0°
# Case D (1919, 1892, 213, 102) 0.66 0.9962669733564605
#
# Processing Case C DJI_0650.JPG_detections.csv -> DJI_0649.JPG_detections.csv with inverted shift: {'y': np.float32(-806.0), 'x': np.float32(3.4560547)} and rotation: 0.0°
# Case C (1910, 2679, 213, 102) 0.66 0.9962669733564605
#
# Processing Case D DJI_0650.JPG_detections.csv -> DJI_0651.JPG_detections.csv with shift: {'y': np.float32(770.0), 'x': np.float32(-3.0)} and rotation: 0.0°
#
# Processing Case C DJI_0651.JPG_detections.csv -> DJI_0650.JPG_detections.csv with inverted shift: {'y': np.float32(-770.0), 'x': np.float32(3.0)} and rotation: 0.0°
# Case C (1910, 3425, 213, 102) 0.61 0.9679052439457114
#
# Processing Case D DJI_0651.JPG_detections.csv -> DJI_0652.JPG_detections.csv with shift: {'y': np.float32(750.6433), 'x': np.float32(-5.971924)} and rotation: 0.0°
#
# Processing Case C DJI_0652.JPG_detections.csv -> DJI_0651.JPG_detections.csv with inverted shift: {'y': np.float32(-750.6433), 'x': np.float32(5.971924)} and rotation: 0.0°
#
# Processing Case D DJI_0652.JPG_detections.csv -> DJI_0653.JPG_detections.csv with shift: {'y': np.float32(771.37946), 'x': np.float32(-21.549805)} and rotation: 0.0°
# Case D (675, 447, 256, 165) 0.64 0.9673166787595134
# Case D (983, 313, 222, 159) 0.63 0.9538222589588257
#
# Processing Case C DJI_0653.JPG_detections.csv -> DJI_0652.JPG_detections.csv with inverted shift: {'y': np.float32(-771.37946), 'x': np.float32(21.549805)} and rotation: 0.0°
# Case C (666, 1248, 256, 159) 0.64 0.9673166787595134
# Case C (978, 1111, 230, 159) 0.63 0.9538222589588257
#
# Processing Case D DJI_0653.JPG_detections.csv -> DJI_0654.JPG_detections.csv with shift: {'y': np.float32(788.2999), 'x': np.float32(-20.160034)} and rotation: 0.0°
# Case D (2432, 190, 247, 165) 0.55 0.9876791046117962
# Case D (1697, 786, 230, 159) 0.64 0.9517952483407831
# Case D (3526, 293, 179, 210) 0.54 0.9804061693092072
#
# Processing Case C DJI_0654.JPG_detections.csv -> DJI_0653.JPG_detections.csv with inverted shift: {'y': np.float32(-788.2999), 'x': np.float32(20.160034)} and rotation: 0.0°
# Case C (1684, 1604, 222, 153) 0.64 0.9517952483407831
# Case C (2419, 1023, 239, 165) 0.55 0.9876791046117962
# Case C (974, 1918, 222, 153) 0.69 0.9783649745825508
# Case C (658, 2054, 256, 165) 0.74 0.9929835080660876
# Case C (3479, 1108, 136, 165) 0.54 0.9804061693092072
#
# Processing Case D DJI_0654.JPG_detections.csv -> DJI_0655.JPG_detections.csv with shift: {'y': np.float32(795.4663), 'x': np.float32(-18.71997)} and rotation: 0.0°
# Case D (3582, 532, 307, 210) 0.86 0.9812868364684467
# Case D (2842, 820, 247, 171) 0.92 0.9677981096089076
#
# Processing Case C DJI_0655.JPG_detections.csv -> DJI_0654.JPG_detections.csv with inverted shift: {'y': np.float32(-795.4663), 'x': np.float32(18.71997)} and rotation: 0.0°
# Case C (3552, 1336, 299, 199) 0.86 0.9812868364684467
# Case C (2817, 1615, 247, 165) 0.92 0.9677981096089076
# Case C (1667, 2379, 222, 153) 0.75 0.9735864637459677
# Case C (2402, 1806, 239, 159) 0.85 0.9874784686818009
# Case C (961, 2693, 230, 153) 0.73 0.9877112465876857
# Case C (654, 2821, 265, 171) 0.64 0.987798133371304
# Case C (3454, 1912, 153, 199) 0.74 0.9591802276143219
#
# Processing Case D DJI_0655.JPG_detections.csv -> DJI_0656.JPG_detections.csv with shift: {'y': np.float32(811.8451), 'x': np.float32(-24.0)} and rotation: 0.0°
# Case D (4805, 780, 205, 136) 0.79 0.9710078212988474
#
# Processing Case C DJI_0656.JPG_detections.csv -> DJI_0655.JPG_detections.csv with inverted shift: {'y': np.float32(-811.8451), 'x': np.float32(24.0)} and rotation: 0.0°
# Case C (2791, 2413, 247, 165) 0.83 0.9597803149904296
# Case C (3518, 2146, 299, 199) 0.92 0.9818047168924741
# Case C (944, 3479, 230, 153) 0.67 0.9799712554989528
# Case C (2376, 2604, 239, 159) 0.83 0.9937289906300756
# Case C (4762, 1593, 188, 131) 0.79 0.9710078212988474
# Case C (1654, 3172, 230, 153) 0.72 0.9727098478837324
# Case C (3437, 2718, 171, 216) 0.82 0.9704307404097925
#
# Processing Case D DJI_0656.JPG_detections.csv -> DJI_0657.JPG_detections.csv with shift: {'y': np.float32(799.69995), 'x': np.float32(-19.0)} and rotation: 0.0°
# Case D (3676, 76, 239, 153) 0.74 0.9731484691777889
# Case D (3073, 142, 247, 159) 0.64 0.9636109722209178
#
# Processing Case C DJI_0657.JPG_detections.csv -> DJI_0656.JPG_detections.csv with inverted shift: {'y': np.float32(-799.69995), 'x': np.float32(19.0)} and rotation: 0.0°
# Case C (3496, 2941, 290, 205) 0.93 0.9872407405360266
# Case C (3655, 897, 247, 165) 0.74 0.9731484691777889
# Case C (3048, 974, 247, 159) 0.64 0.9636109722209178
# Case C (2355, 3382, 230, 165) 0.74 0.9837150810095532
# Case C (3407, 3505, 179, 239) 0.79 0.9892427917451956
# Case C (4728, 2388, 188, 125) 0.8 0.9936354181597417
#
# Processing Case D DJI_0657.JPG_detections.csv -> DJI_0658.JPG_detections.csv with shift: {'y': np.float32(818.1599), 'x': np.float32(-18.71997)} and rotation: 0.0°
# Case D (4805, 322, 188, 119) 0.71 0.9675962958948331
#
# Processing Case C DJI_0658.JPG_detections.csv -> DJI_0657.JPG_detections.csv with inverted shift: {'y': np.float32(-818.1599), 'x': np.float32(18.71997)} and rotation: 0.0°
# Case C (3625, 1715, 239, 159) 0.88 0.9823386511672255
# Case C (4766, 1148, 179, 119) 0.71 0.9675962958948331
# Case C (4693, 3183, 188, 131) 0.6 0.988955992591219
# Case C (3030, 1792, 230, 153) 0.9 0.9914335351325015
#
# Processing Case D DJI_0658.JPG_detections.csv -> DJI_0659.JPG_detections.csv with shift: {'y': np.float32(808.7042), 'x': np.float32(-24.47998)} and rotation: 0.0°
#
# Processing Case C DJI_0659.JPG_detections.csv -> DJI_0658.JPG_detections.csv with inverted shift: {'y': np.float32(-808.7042), 'x': np.float32(24.47998)} and rotation: 0.0°
# Case C (3595, 2505, 247, 165) 0.76 0.990197437602682
# Case C (4732, 1952, 179, 119) 0.83 0.9758820228216264
# Case C (2996, 2590, 230, 153) 0.8 0.97925269531501
#
# Processing Case D DJI_0659.JPG_detections.csv -> DJI_0660.JPG_detections.csv with shift: {'y': np.float32(809.3013), 'x': np.float32(-24.0)} and rotation: 0.0°
# Case D (115, 253, 179, 131) 0.66 0.9802534965340433
#
# Processing Case C DJI_0660.JPG_detections.csv -> DJI_0659.JPG_detections.csv with inverted shift: {'y': np.float32(-809.3013), 'x': np.float32(24.0)} and rotation: 0.0°
# Case C (3565, 3274, 239, 176) 0.59 0.9825420539587125
# Case C (4693, 2733, 188, 131) 0.55 0.9888715923522133
# Case C (98, 1083, 162, 125) 0.66 0.9802534965340433
#
# Processing Case D DJI_0660.JPG_detections.csv -> DJI_0661.JPG_detections.csv with shift: {'y': np.float32(811.4001), 'x': np.float32(-27.0)} and rotation: 0.0°
# Case D (555, 880, 342, 199) 0.77 0.994291271460351
# Case D (996, 709, 196, 131) 0.62 0.9788060523350299
# Case D (2248, 182, 273, 182) 0.72 0.9863739145504947
#
# Processing Case C DJI_0661.JPG_detections.csv -> DJI_0660.JPG_detections.csv with inverted shift: {'y': np.float32(-811.4001), 'x': np.float32(27.0)} and rotation: 0.0°
# Case C (983, 1544, 205, 136) 0.62 0.9788060523350299
# Case C (2231, 1017, 273, 188) 0.72 0.9863739145504947
# Case C (542, 1710, 333, 205) 0.77 0.994291271460351
# Case C (4655, 3514, 179, 131) 0.56 0.9762074274027525
# Case C (89, 1909, 162, 125) 0.65 0.9903059491695562
#
# Processing Case D DJI_0661.JPG_detections.csv -> DJI_0662.JPG_detections.csv with shift: {'y': np.float32(830.0), 'x': np.float32(-23.0)} and rotation: 0.0°
# Case D (2706, 852, 179, 119) 0.79 0.9953970862106376
#
# Processing Case C DJI_0662.JPG_detections.csv -> DJI_0661.JPG_detections.csv with inverted shift: {'y': np.float32(-830.0), 'x': np.float32(23.0)} and rotation: 0.0°
# Case C (2205, 1863, 273, 182) 0.82 0.9900686415140092
# Case C (974, 2379, 205, 142) 0.82 0.9866623234814399
# Case C (2693, 1690, 188, 108) 0.79 0.9953970862106376
#
# Processing Case D DJI_0662.JPG_detections.csv -> DJI_0663.JPG_detections.csv with shift: {'y': np.float32(800.3221), 'x': np.float32(-17.915771)} and rotation: 0.0°
#
# Processing Case C DJI_0663.JPG_detections.csv -> DJI_0662.JPG_detections.csv with inverted shift: {'y': np.float32(-800.3221), 'x': np.float32(17.915771)} and rotation: 0.0°
# Case C (957, 3166, 205, 142) 0.82 0.9924761441716613
# Case C (2188, 2653, 273, 188) 0.89 0.9963914646792567
#
# Processing Case D DJI_0663.JPG_detections.csv -> DJI_0664.JPG_detections.csv with shift: {'y': np.float32(828.0), 'x': np.float32(-19.906494)} and rotation: 0.0°
# Case D (5031, 401, 179, 256) 0.75 0.9881692615735794
#
# Processing Case C DJI_0664.JPG_detections.csv -> DJI_0663.JPG_detections.csv with inverted shift: {'y': np.float32(-828.0), 'x': np.float32(19.906494)} and rotation: 0.0°
# Case C (4988, 1225, 179, 262) 0.75 0.9881692615735794
# Case C (2171, 3448, 273, 193) 0.69 0.9794648124206243
#
# Processing Case D DJI_0664.JPG_detections.csv -> DJI_0665.JPG_detections.csv with shift: {'y': np.float32(849.6001), 'x': np.float32(-24.191895)} and rotation: 0.0°
# Case D (1470, 458, 239, 165) 0.84 0.9832709402408394
#
# Processing Case C DJI_0665.JPG_detections.csv -> DJI_0664.JPG_detections.csv with inverted shift: {'y': np.float32(-849.6001), 'x': np.float32(24.191895)} and rotation: 0.0°
# Case C (1457, 1313, 230, 153) 0.84 0.9832709402408394
# Case C (4946, 2063, 179, 250) 0.75 0.9981566322734506
#
# Processing Case D DJI_0665.JPG_detections.csv -> DJI_0666.JPG_detections.csv with shift: {'y': np.float32(808.7041), 'x': np.float32(-32.0)} and rotation: 0.0°
# Case D (3287, 581, 162, 114) 0.9 0.9732111365610318
#
# Processing Case C DJI_0666.JPG_detections.csv -> DJI_0665.JPG_detections.csv with inverted shift: {'y': np.float32(-808.7041), 'x': np.float32(32.0)} and rotation: 0.0°
# Case C (4903, 2855, 179, 250) 0.78 0.9888935055749782
# Case C (1449, 2120, 230, 148) 0.79 0.9934448630107505
# Case C (3257, 1393, 171, 119) 0.9 0.9732111365610318
#
# Processing Case D DJI_0666.JPG_detections.csv -> DJI_0667.JPG_detections.csv with shift: {'y': np.float32(815.61597), 'x': np.float32(-29.859863)} and rotation: 0.0°
# Case D (5198, 538, 239, 165) 0.69 0.9958499242219424
# Case D (3971, 96, 162, 193) 0.81 0.9843020006350649
#
# Processing Case C DJI_0667.JPG_detections.csv -> DJI_0666.JPG_detections.csv with inverted shift: {'y': np.float32(-815.61597), 'x': np.float32(29.859863)} and rotation: 0.0°
# Case C (5151, 1373, 230, 159) 0.69 0.9958499242219424
# Case C (1423, 2932, 247, 153) 0.89 0.9913921914458865
# Case C (3937, 900, 162, 228) 0.81 0.9843020006350649
# Case C (3227, 2208, 162, 119) 0.94 0.9979296849299435
#
# Processing Case D DJI_0667.JPG_detections.csv -> DJI_0668.JPG_detections.csv with shift: {'y': np.float32(803.52026), 'x': np.float32(-25.0)} and rotation: 0.0°
# Case D (1645, 88, 316, 176) 0.79 0.9922344537826638
# Case D (333, 1026, 205, 148) 0.69 0.9653371538028613
# Case D (1859, 361, 247, 142) 0.65 0.9843266013607268
#
# Processing Case C DJI_0668.JPG_detections.csv -> DJI_0667.JPG_detections.csv with inverted shift: {'y': np.float32(-803.52026), 'x': np.float32(25.0)} and rotation: 0.0°
# Case C (329, 1843, 213, 142) 0.69 0.9653371538028613
# Case C (1633, 906, 307, 193) 0.79 0.9922344537826638
# Case C (5121, 2185, 222, 165) 0.86 0.991913190941704
# Case C (3907, 1718, 153, 233) 0.83 0.9944656919431636
# Case C (1842, 1191, 247, 148) 0.65 0.9843266013607268
#
# Processing Case D DJI_0668.JPG_detections.csv -> DJI_0669.JPG_detections.csv with shift: {'y': np.float32(838.0801), 'x': np.float32(-26.87378)} and rotation: 0.0°
# Case D (2441, 664, 213, 165) 0.92 0.973917926191481
#
# Processing Case C DJI_0669.JPG_detections.csv -> DJI_0668.JPG_detections.csv with inverted shift: {'y': np.float32(-838.0801), 'x': np.float32(26.87378)} and rotation: 0.0°
# Case C (1615, 1755, 307, 193) 0.85 0.958426914838229
# Case C (1829, 2037, 239, 142) 0.8 0.9840904394568776
# Case C (3873, 2547, 153, 228) 0.84 0.9857002768609747
# Case C (5070, 3012, 222, 165) 0.71 0.9955691442548424
# Case C (2415, 1507, 213, 153) 0.92 0.973917926191481
#
# Processing Case D DJI_0669.JPG_detections.csv -> DJI_0670.JPG_detections.csv with shift: {'y': np.float32(350.1), 'x': np.float32(109.91058)} and rotation: 0.0°
# Case D (320, 2679, 213, 148) 0.81 0.9946501996541179
# Case D (2821, 441, 153, 245) 0.77 0.9898841676024528
# Case D (115, 65, 230, 131) 0.67 0.9652694602706291
#
# Processing Case C DJI_0670.JPG_detections.csv -> DJI_0669.JPG_detections.csv with inverted shift: {'y': np.float32(-350.1), 'x': np.float32(-109.91058)} and rotation: 0.0°
# Case C (448, 3029, 213, 142) 0.81 0.9946501996541179
# Case C (1731, 2111, 316, 199) 0.91 0.9875728303098322
# Case C (5189, 3328, 239, 171) 0.62 0.9705360440140716
# Case C (2915, 800, 171, 245) 0.77 0.9898841676024528
# Case C (3988, 2872, 162, 228) 0.76 0.9898582646955423
# Case C (1932, 2388, 239, 148) 0.91 0.9895346072380136
# Case C (213, 418, 256, 176) 0.67 0.9652694602706291
# Case C (2522, 1852, 205, 148) 0.9 0.9964526782898593
#
# Processing Case D DJI_0670.JPG_detections.csv -> DJI_0671.JPG_detections.csv with shift: {'y': np.float64(-1516.1522459786734), 'x': np.float64(-21.17085472999358)} and rotation: 180.8°
#
# Processing Case C DJI_0671.JPG_detections.csv -> DJI_0670.JPG_detections.csv with inverted shift: {'y': np.float64(-1516.1522459786734), 'x': np.float64(-21.17085472999358)} and rotation: 180.8°
#
# Processing Case D DJI_0671.JPG_detections.csv -> DJI_0672.JPG_detections.csv with shift: {'y': np.float32(724.32007), 'x': np.float32(-74.64966)} and rotation: -0.4000000000000057°
# Case D (2167, 1447, 230, 159) 0.91 0.9642789752616123
# Case D (3612, 689, 196, 148) 0.57 0.9665923641985952
# Case D (132, 1077, 179, 228) 0.6 0.9649924703849369
# Case D (1637, 1997, 196, 165) 0.81 0.992516727083939
#
# Processing Case C DJI_0672.JPG_detections.csv -> DJI_0671.JPG_detections.csv with inverted shift: {'y': np.float32(-724.32007), 'x': np.float32(74.64966)} and rotation: -0.4000000000000057°
# Case C (2103, 2171, 239, 159) 0.91 0.9642789752616123
# Case C (3552, 1444, 196, 142) 0.57 0.9665923641985952
# Case C (72, 1764, 145, 233) 0.6 0.9649924703849369
# Case C (1564, 2707, 205, 171) 0.81 0.992516727083939
#
# Processing Case D DJI_0672.JPG_detections.csv -> DJI_0673.JPG_detections.csv with shift: {'y': np.float32(796.6079), 'x': np.float32(-72.161316)} and rotation: -0.20000000000001705°
# Case D (2312, 2442, 282, 199) 0.88 0.9808857759812949
#
# Processing Case C DJI_0673.JPG_detections.csv -> DJI_0672.JPG_detections.csv with inverted shift: {'y': np.float32(-796.6079), 'x': np.float32(72.161316)} and rotation: -0.20000000000001705°
# Case C (2240, 3229, 290, 199) 0.88 0.9808857759812949
# Case C (1500, 3491, 213, 176) 0.8 0.9640269537009089
# Case C (2026, 2978, 239, 153) 0.84 0.982973580688106
#
# Processing Case D DJI_0673.JPG_detections.csv -> DJI_0674.JPG_detections.csv with shift: {'y': np.float32(781.3325), 'x': np.float32(-44.789764)} and rotation: -0.09999999999999432°
# Case D (3479, 2245, 188, 148) 0.93 0.9698554954676744
# Case D (2334, 416, 239, 171) 0.68 0.9687043189798066
#
# Processing Case C DJI_0674.JPG_detections.csv -> DJI_0673.JPG_detections.csv with inverted shift: {'y': np.float32(-781.3325), 'x': np.float32(44.789764)} and rotation: -0.09999999999999432°
# Case C (3428, 3026, 188, 148) 0.93 0.9698554954676744
# Case C (2295, 1225, 230, 159) 0.68 0.9687043189798066
#
# Processing Case D DJI_0674.JPG_detections.csv -> DJI_0675.JPG_detections.csv with shift: {'y': np.float32(801.792), 'x': np.float32(-24.47998)} and rotation: 0.0°
# Case D (4984, 171, 222, 159) 0.8 0.9647412260710674
#
# Processing Case C DJI_0675.JPG_detections.csv -> DJI_0674.JPG_detections.csv with inverted shift: {'y': np.float32(-801.792), 'x': np.float32(24.47998)} and rotation: 0.0°
# Case C (2274, 2029, 239, 159) 0.94 0.9790687486366261
# Case C (4950, 983, 205, 142) 0.8 0.9647412260710674
#
# Processing Case D DJI_0675.JPG_detections.csv -> DJI_0676.JPG_detections.csv with shift: {'y': np.float32(771.51746), 'x': np.float32(-17.915894)} and rotation: 0.0°
#
# Processing Case C DJI_0676.JPG_detections.csv -> DJI_0675.JPG_detections.csv with inverted shift: {'y': np.float32(-771.51746), 'x': np.float32(17.915894)} and rotation: 0.0°
# Case C (4916, 1781, 205, 142) 0.6 0.9730418676948361
#
# Processing Case D DJI_0676.JPG_detections.csv -> DJI_0677.JPG_detections.csv with shift: {'y': np.float32(792.5768), 'x': np.float32(0.0)} and rotation: -0.09999999999999432°
# Case D (2252, 2830, 230, 165) 0.6 0.9624427742091737
#
# Processing Case C DJI_0677.JPG_detections.csv -> DJI_0676.JPG_detections.csv with inverted shift: {'y': np.float32(-792.5768), 'x': np.float32(-0.0)} and rotation: -0.09999999999999432°
# Case C (4899, 2570, 205, 148) 0.81 0.9931235392695911
# Case C (2261, 3593, 230, 108) 0.6 0.9624427742091737
#
# Processing Case D DJI_0677.JPG_detections.csv -> DJI_0678.JPG_detections.csv with shift: {'y': np.float32(841.0525), 'x': np.float32(2.8798828)} and rotation: 0.0°
# Case D (2650, 119, 205, 148) 0.87 0.9980094693584031
#
# Processing Case C DJI_0678.JPG_detections.csv -> DJI_0677.JPG_detections.csv with inverted shift: {'y': np.float32(-841.0525), 'x': np.float32(-2.8798828)} and rotation: 0.0°
# Case C (2659, 966, 205, 142) 0.87 0.9980094693584031
#
# ...
# Case C (3672, 892, 94, 222) 0.83 0.9640871075867065
# Case C (3274, 880, 85, 199) 0.81 0.9900016796175466
# Case C (4672, 1211, 94, 188) 0.78 0.9796848871870494
# Case C (4638, 715, 111, 222) 0.53 0.9847836193241885
# Case C (3514, 1162, 102, 216) 0.86 0.9899702498841209
# Case C (5142, 820, 111, 171) 0.77 0.9951226032666045
# Case C (4317, 923, 136, 273) 0.8 0.9955484606911778
#
# Processing Case D DJI_0714.JPG_detections.csv -> DJI_0715.JPG_detections.csv with shift: {'y': np.float32(357.69592), 'x': np.float32(-32.0)} and rotation: 0.0°
# Case D (2244, 82, 247, 165) 0.82 0.9828162884103491
# Case D (2436, 723, 256, 250) 0.8 0.9958445317769513
# Case D (2992, 270, 102, 210) 0.84 0.9833971628673894
# Case D (457, 1379, 145, 250) 0.64 0.9924312746723241
# Case D (3732, 684, 179, 193) 0.92 0.9886372152699617
# Case D (2445, 122, 256, 153) 0.73 0.9735320439777023
# Case D (2423, 327, 230, 108) 0.63 0.9698645819796743
# Case D (2812, 302, 102, 205) 0.85 0.9859775994544628
# Case D (2466, 478, 196, 91) 0.6 0.9828821604586457
# Case D (5177, 1057, 111, 210) 0.8 0.9577710462972706
#
# Processing Case C DJI_0715.JPG_detections.csv -> DJI_0714.JPG_detections.csv with inverted shift: {'y': np.float32(-357.69592), 'x': np.float32(32.0)} and rotation: 0.0°
# Case C (2218, 453, 247, 176) 0.82 0.9828162884103491
# Case C (2526, 1687, 145, 171) 0.88 0.9903697843363323
# Case C (3142, 1462, 111, 210) 0.86 0.9828515197049856
# Case C (2398, 1102, 247, 233) 0.8 0.9958445317769513
# Case C (3702, 1045, 171, 188) 0.92 0.9886372152699617
# Case C (2894, 1159, 111, 222) 0.86 0.9813947000153128
# Case C (4959, 1322, 171, 216) 0.71 0.9875794459332528
# Case C (444, 1761, 136, 250) 0.64 0.9924312746723241
# Case C (2432, 855, 179, 91) 0.6 0.9828821604586457
# Case C (4753, 1342, 205, 96) 0.68 0.9838733776560785
# Case C (2954, 635, 111, 210) 0.84 0.9833971628673894
# Case C (2778, 672, 102, 205) 0.85 0.9859775994544628
# Case C (2398, 706, 230, 102) 0.63 0.9698645819796743
# Case C (5125, 1159, 111, 165) 0.62 0.9962859932114277
# Case C (3107, 1208, 128, 228) 0.9 0.9899550086721145
# Case C (3633, 1242, 102, 228) 0.81 0.9755289483337165
# Case C (2415, 501, 247, 148) 0.73 0.9735320439777023
# Case C (2894, 1450, 94, 210) 0.9 0.9936560762016037
# Case C (2475, 1462, 111, 222) 0.82 0.9919671088788302
# Case C (2594, 1521, 94, 216) 0.79 0.9786085659610597
# Case C (4612, 1065, 111, 216) 0.84 0.9908450146344557
# Case C (4646, 1558, 94, 199) 0.79 0.9944514284857032
# Case C (2624, 1285, 102, 210) 0.84 0.9797575143395424
# Case C (5151, 1405, 128, 210) 0.8 0.9577710462972706
# Case C (3479, 1516, 102, 205) 0.9 0.9965205722061173
# Case C (3505, 1245, 119, 245) 0.96 0.9959229575076028
# Case C (3240, 1236, 85, 205) 0.93 0.9943203742617963
#
# Processing Case D DJI_0715.JPG_detections.csv -> DJI_0716.JPG_detections.csv with shift: {'y': np.float64(-15.299683399435327), 'x': np.float64(0.14033429312869455)} and rotation: -180.9°
#
# Processing Case C DJI_0716.JPG_detections.csv -> DJI_0715.JPG_detections.csv with inverted shift: {'y': np.float64(15.299683399435327), 'x': np.float64(-0.14033429312869455)} and rotation: -180.9°
#
# Processing Case D DJI_0716.JPG_detections.csv -> DJI_0717.JPG_detections.csv with shift: {'y': np.float32(618.0988), 'x': np.float32(77.63562)} and rotation: 0.40000000000000036°
# Case D (1218, 2180, 179, 222) 0.68 0.9912115803182695
# Case D (3351, 2436, 119, 210) 0.68 0.9857557107103806
# Case D (2530, 2519, 188, 193) 0.7 0.9770866242420418
# Case D (3843, 2516, 230, 222) 0.65 0.9675954228759739
# Case D (1436, 2163, 205, 108) 0.56 0.9795033229435912
# Case D (3723, 2408, 128, 222) 0.55 0.9895409897102823
# Case D (3116, 2117, 111, 210) 0.72 0.9749943401477466
# Case D (3001, 2345, 85, 199) 0.56 0.9871620181435706
# Case D (3736, 1923, 136, 176) 0.6 0.9719018720393082
# Case D (3364, 2140, 111, 222) 0.79 0.9676786018033285
# Case D (2607, 2322, 119, 233) 0.71 0.9810676683574467
# Case D (1038, 2331, 111, 171) 0.55 0.9858944611833359
# Case D (3779, 2160, 102, 216) 0.61 0.9806437383038289
# Case D (3667, 2086, 102, 228) 0.65 0.9988860142728468
# Case D (2740, 2322, 111, 233) 0.83 0.9684053915614954
# Case D (3620, 2319, 94, 216) 0.57 0.9921541103695856
# Case D (1581, 2456, 102, 216) 0.57 0.9759335939204618
# Case D (2218, 2271, 145, 290) 0.8 0.9946148377844601
# Case D (3129, 2388, 102, 216) 0.58 0.9716604305011628
# Case D (1919, 2271, 128, 279) 0.77 0.9851271511275976
# Case D (1021, 2077, 128, 222) 0.57 0.9899330088164262
# Case D (1838, 2622, 153, 364) 0.71 0.9943009159257988
# Case D (2783, 2054, 94, 210) 0.82 0.9983334261109638
# Case D (1752, 2356, 136, 222) 0.58 0.9857535533161033
# Case D (2060, 2294, 153, 347) 0.8 0.9621258003910688
# Case D (2637, 2032, 128, 222) 0.82 0.99117566422395
#
# Processing Case C DJI_0717.JPG_detections.csv -> DJI_0716.JPG_detections.csv with inverted shift: {'y': np.float32(-618.0988), 'x': np.float32(-77.63562)} and rotation: 0.40000000000000036°
# Case C (2637, 3143, 196, 188) 0.7 0.9770866242420418
# Case C (3206, 2724, 102, 216) 0.72 0.9749943401477466
# Case C (1308, 2827, 171, 216) 0.68 0.9912115803182695
# Case C (1680, 3095, 111, 228) 0.57 0.9759335939204618
# Case C (3445, 3040, 119, 222) 0.68 0.9857557107103806
# Case C (1530, 2804, 205, 102) 0.56 0.9795033229435912
# Case C (3826, 2510, 145, 165) 0.6 0.9719018720393082
# Case C (3099, 2949, 94, 199) 0.56 0.9871620181435706
# Case C (3714, 2912, 94, 216) 0.57 0.9921541103695856
# Case C (1132, 2978, 111, 176) 0.55 0.9858944611833359
# Case C (3950, 3112, 239, 239) 0.65 0.9675954228759739
# Case C (2701, 2932, 119, 233) 0.71 0.9810676683574467
# Case C (2308, 2884, 153, 307) 0.8 0.9946148377844601
# Case C (3449, 2750, 111, 199) 0.79 0.9676786018033285
# Case C (1855, 2995, 136, 222) 0.58 0.9857535533161033
# Case C (3826, 3001, 128, 233) 0.55 0.9895409897102823
# Case C (3757, 2679, 111, 228) 0.65 0.9988860142728468
# Case C (1115, 2733, 128, 222) 0.57 0.9899330088164262
# Case C (2825, 2935, 128, 239) 0.83 0.9684053915614954
# Case C (2009, 2898, 119, 267) 0.77 0.9851271511275976
# Case C (1936, 3254, 145, 364) 0.71 0.9943009159257988
# Case C (2868, 2667, 94, 216) 0.82 0.9983334261109638
# Case C (3227, 2986, 111, 228) 0.58 0.9716604305011628
# Case C (2146, 2932, 171, 313) 0.8 0.9621258003910688
# Case C (3868, 2747, 94, 216) 0.61 0.9806437383038289
# Case C (2723, 2644, 128, 239) 0.82 0.99117566422395
#
# Processing Case D DJI_0717.JPG_detections.csv -> DJI_0718.JPG_detections.csv with shift: {'y': np.float32(646.08374), 'x': np.float32(86.400024)} and rotation: 0.20000000000000018°
# Case D (2218, 410, 111, 216) 0.52 0.951737754130271
#
# Processing Case C DJI_0718.JPG_detections.csv -> DJI_0717.JPG_detections.csv with inverted shift: {'y': np.float32(-646.08374), 'x': np.float32(-86.400024)} and rotation: 0.20000000000000018°
# Case C (2274, 1071, 119, 216) 0.52 0.951737754130271
# Case C (3548, 3394, 102, 188) 0.75 0.9903564172708532
# Case C (1402, 3482, 171, 228) 0.85 0.9590706418612841
# Case C (3300, 3365, 102, 210) 0.82 0.960956160148345
# Case C (3821, 3536, 85, 199) 0.52 0.958156896678331
# Case C (1205, 3385, 119, 239) 0.87 0.9826787856923239
# Case C (3189, 3562, 85, 159) 0.63 0.9590700777121806
# Case C (2928, 3551, 111, 193) 0.58 0.9805543790080584
# Case C (2257, 3531, 153, 233) 0.53 0.9910550826313368
#
# Processing Case D DJI_0718.JPG_detections.csv -> DJI_0719.JPG_detections.csv with shift: {'y': np.float32(677.0), 'x': np.float32(52.80005)} and rotation: 0.09999999999999964°
#
# Processing Case C DJI_0719.JPG_detections.csv -> DJI_0718.JPG_detections.csv with inverted shift: {'y': np.float32(-677.0), 'x': np.float32(-52.80005)} and rotation: 0.09999999999999964°
# Case C (2325, 1761, 119, 205) 0.86 0.992559568732981
#
# Processing Case D DJI_0719.JPG_detections.csv -> DJI_0720.JPG_detections.csv with shift: {'y': np.float32(683.0442), 'x': np.float32(23.887695)} and rotation: 0.0°
# Case D (1534, 701, 230, 182) 0.71 0.9903570747732455
#
# Processing Case C DJI_0720.JPG_detections.csv -> DJI_0719.JPG_detections.csv with inverted shift: {'y': np.float32(-683.0442), 'x': np.float32(-23.887695)} and rotation: 0.0°
# Case C (1564, 1410, 239, 176) 0.71 0.9903570747732455
# Case C (2355, 2448, 111, 210) 0.87 0.9775888458144087
#
# Processing Case D DJI_0720.JPG_detections.csv -> DJI_0721.JPG_detections.csv with shift: {'y': np.float32(717.46594), 'x': np.float32(17.418213)} and rotation: 0.10000000000000053°
# Case D (2988, 798, 128, 216) 0.8 0.9751961282779351
#
# Processing Case C DJI_0721.JPG_detections.csv -> DJI_0720.JPG_detections.csv with inverted shift: {'y': np.float32(-717.46594), 'x': np.float32(-17.418213)} and rotation: 0.10000000000000053°
# Case C (1603, 2128, 247, 165) 0.79 0.9825694681812311
# Case C (3001, 1533, 136, 216) 0.8 0.9751961282779351
# Case C (2364, 3143, 111, 210) 0.7 0.9707359806803848
#
# Processing Case D DJI_0721.JPG_detections.csv -> DJI_0722.JPG_detections.csv with shift: {'y': np.float32(717.1201), 'x': np.float32(5.971924)} and rotation: 0.0°
# Case D (5044, 182, 324, 228) 0.51 0.9812454621262703
# Case D (3325, 1484, 171, 199) 0.64 0.9815471331962847
# Case D (3625, 1379, 256, 193) 0.54 0.9829360849526333
# Case D (5356, 68, 213, 136) 0.59 0.9755558178291789
#
# Processing Case C DJI_0722.JPG_detections.csv -> DJI_0721.JPG_detections.csv with inverted shift: {'y': np.float32(-717.1201), 'x': np.float32(-5.971924)} and rotation: 0.0°
# Case C (5035, 963, 324, 216) 0.51 0.9812454621262703
# Case C (3599, 2134, 256, 188) 0.54 0.9829360849526333
# Case C (1607, 2844, 256, 171) 0.93 0.9933951491772399
# Case C (3338, 2237, 179, 188) 0.64 0.9815471331962847
# Case C (5352, 817, 239, 165) 0.59 0.9755558178291789
#
# Processing Case D DJI_0722.JPG_detections.csv -> DJI_0723.JPG_detections.csv with shift: {'y': np.float32(704.4001), 'x': np.float32(-3.0)} and rotation: 0.0°
# Case D (3706, 319, 111, 205) 0.62 0.9948182766018165
# Case D (3868, 2029, 196, 136) 0.72 0.9835800177159612
# Case D (3599, 339, 119, 222) 0.69 0.9687437728873424
# Case D (3492, 544, 111, 210) 0.69 0.9839709199160397
#
# Processing Case C DJI_0723.JPG_detections.csv -> DJI_0722.JPG_detections.csv with inverted shift: {'y': np.float32(-704.4001), 'x': np.float32(3.0)} and rotation: 0.0°
# Case C (5018, 1698, 307, 205) 0.69 0.9910663021264098
# Case C (3330, 2946, 179, 193) 0.9 0.992268162915149
# Case C (1603, 3536, 265, 176) 0.84 0.993234605094873
# Case C (3586, 2858, 247, 188) 0.75 0.992992032273218
# Case C (5335, 1561, 239, 148) 0.54 0.9879069607274601
# Case C (3856, 2750, 188, 131) 0.72 0.9835800177159612
# Case C (3595, 1077, 128, 216) 0.69 0.9687437728873424
# Case C (3697, 1060, 128, 205) 0.62 0.9948182766018165
# Case C (3484, 1279, 111, 210) 0.69 0.9839709199160397
#
# Processing Case D DJI_0723.JPG_detections.csv -> DJI_0724.JPG_detections.csv with shift: {'y': np.float32(731.1246), 'x': np.float32(-11.100098)} and rotation: 0.0°
# Case D (4398, 726, 213, 131) 0.52 0.9875408862618973
# Case D (3471, 507, 222, 136) 0.65 0.9896809760042434
# Case D (2099, 1943, 94, 182) 0.93 0.9880457252459396
#
# Processing Case C DJI_0724.JPG_detections.csv -> DJI_0723.JPG_detections.csv with inverted shift: {'y': np.float32(-731.1246), 'x': np.float32(11.100098)} and rotation: 0.0°
# Case C (4993, 2456, 307, 193) 0.7 0.992836454586588
# Case C (4377, 1493, 205, 125) 0.52 0.9875408862618973
# Case C (5309, 2317, 239, 142) 0.64 0.9881084250791288
# Case C (3838, 3479, 188, 131) 0.9 0.9651108427548319
# Case C (3685, 1812, 119, 205) 0.76 0.9830168820172623
# Case C (3462, 1265, 222, 125) 0.65 0.9896809760042434
# Case C (3475, 2026, 111, 222) 0.83 0.990480885532047
# Case C (3569, 3568, 247, 159) 0.75 0.9644277751119276
# Case C (3582, 1832, 119, 222) 0.75 0.9964439029893282
# Case C (2090, 2676, 94, 176) 0.93 0.9880457252459396
#
# Processing Case D DJI_0724.JPG_detections.csv -> DJI_0725.JPG_detections.csv with shift: {'y': np.float32(719.0), 'x': np.float32(-2.9858398)} and rotation: 0.0°
# Case D (1940, 71, 119, 142) 0.59 0.9738999916700224
# Case D (996, 507, 111, 193) 0.68 0.9883990245988221
# Case D (342, 575, 136, 216) 0.76 0.9777628954222978
# Case D (1829, 897, 188, 108) 0.78 0.9609737965513145
#
# Processing Case C DJI_0725.JPG_detections.csv -> DJI_0724.JPG_detections.csv with inverted shift: {'y': np.float32(-719.0), 'x': np.float32(2.9858398)} and rotation: 0.0°
# Case C (4976, 3177, 307, 199) 0.89 0.9866489673078187
# Case C (3458, 1995, 213, 125) 0.81 0.9892599346087557
# Case C (3672, 2536, 111, 205) 0.8 0.9870595178055379
# Case C (1953, 789, 111, 188) 0.59 0.9738999916700224
# Case C (5288, 3040, 230, 142) 0.81 0.9746559704277873
# Case C (4364, 2223, 213, 125) 0.77 0.9657619994522753
# Case C (1825, 1627, 196, 96) 0.78 0.9609737965513145
# Case C (3467, 2738, 111, 210) 0.86 0.995493862601148
# Case C (3573, 2553, 119, 216) 0.88 0.9883714341939384
# Case C (354, 1299, 128, 205) 0.76 0.9777628954222978
# Case C (1013, 1228, 111, 199) 0.68 0.9883990245988221
#
# Processing Case D DJI_0725.JPG_detections.csv -> DJI_0726.JPG_detections.csv with shift: {'y': np.float32(717.6001), 'x': np.float32(-9.5998535)} and rotation: 0.0°
# Case D (2496, 555, 119, 245) 0.78 0.9909091846638459
# Case D (5403, 806, 136, 119) 0.53 0.9630042787690924
#
# Processing Case C DJI_0726.JPG_detections.csv -> DJI_0725.JPG_detections.csv with inverted shift: {'y': np.float32(-717.6001), 'x': np.float32(9.5998535)} and rotation: 0.0°
# Case C (1953, 1521, 111, 182) 0.73 0.9887416957199346
# Case C (2492, 1293, 128, 239) 0.78 0.9909091846638459
# Case C (3445, 2713, 205, 114) 0.88 0.9778341348259142
# Case C (4351, 2938, 205, 119) 0.92 0.9952957893624169
# Case C (1021, 1966, 111, 171) 0.6 0.9708657471875477
# Case C (3655, 3246, 111, 210) 0.82 0.9797538351714112
# Case C (1825, 2345, 196, 96) 0.9 0.9793476491831106
# Case C (3556, 3263, 119, 222) 0.83 0.9920592444354568
# Case C (3449, 3442, 111, 216) 0.76 0.9843879830269725
# Case C (371, 2014, 128, 199) 0.64 0.9737799800894832
# Case C (5386, 1550, 171, 125) 0.53 0.9630042787690924
#
# Processing Case D DJI_0726.JPG_detections.csv -> DJI_0727.JPG_detections.csv with shift: {'y': np.float32(723.7446), 'x': np.float32(1.4399414)} and rotation: 0.0°
# Case D (465, 621, 128, 216) 0.69 0.9736742829425683
# Case D (213, 618, 136, 222) 0.74 0.9830115162784082
# Case D (76, 615, 153, 239) 0.66 0.9954382491706883
#
# Processing Case C DJI_0727.JPG_detections.csv -> DJI_0726.JPG_detections.csv with inverted shift: {'y': np.float32(-723.7446), 'x': np.float32(-1.4399414)} and rotation: 0.0°
# Case C (1957, 2251, 102, 182) 0.86 0.9772783898570626
# Case C (2488, 2029, 119, 239) 0.83 0.9876910991341299
# Case C (3441, 3428, 213, 119) 0.82 0.9683812164824368
# Case C (1825, 3066, 196, 102) 0.93 0.9776048150679024
# Case C (483, 1356, 111, 216) 0.69 0.9736742829425683
# Case C (98, 1356, 145, 228) 0.66 0.9954382491706883
# Case C (226, 1356, 128, 216) 0.74 0.9830115162784082
# Case C (371, 2738, 111, 188) 0.82 0.9921027131276955
# Case C (5377, 2302, 188, 114) 0.56 0.9667033610780548
#
# Processing Case D DJI_0727.JPG_detections.csv -> DJI_0728.JPG_detections.csv with shift: {'y': np.float32(723.6001), 'x': np.float32(-1.4400635)} and rotation: 0.0°
# Case D (602, 1328, 94, 182) 0.83 0.9876305314332915
# Case D (3702, 2448, 410, 176) 0.82 0.9650265834239506
#
# Processing Case C DJI_0728.JPG_detections.csv -> DJI_0727.JPG_detections.csv with inverted shift: {'y': np.float32(-723.6001), 'x': np.float32(1.4400635)} and rotation: 0.0°
# Case C (1953, 2975, 111, 182) 0.92 0.980429290805679
# Case C (3685, 3183, 427, 176) 0.82 0.9650265834239506
# Case C (2483, 2758, 128, 239) 0.89 0.9912680849385865
# Case C (102, 2089, 136, 222) 0.85 0.9754618967255786
# Case C (491, 2091, 111, 205) 0.76 0.9921725021104351
# Case C (5365, 3040, 213, 119) 0.7 0.9902521649629467
# Case C (607, 2057, 102, 171) 0.83 0.9876305314332915
# Case C (239, 2083, 119, 222) 0.77 0.98503099463116
#
# Processing Case D DJI_0728.JPG_detections.csv -> DJI_0729.JPG_detections.csv with shift: {'y': np.float32(711.245), 'x': np.float32(-3.583252)} and rotation: 0.0°
#
# Processing Case B DJI_0729.JPG_detections.csv -> DJI_0728.JPG_detections.csv with inverted shift: {'y': np.float32(-711.245), 'x': np.float32(3.583252)} and rotation: 0.0°
# Case B [491, 2798, 94, 182] 0.75 0.9579210199606966
# Case B [2488, 3462, 119, 245] 0.82 0.988842319987999

# %% [markdown]
# # Visualisation with YOLO BBs

# %%
import cv2
import pandas as pd
import matplotlib.pyplot as plt
import os

def draw_bboxes_from_csv(image_path, csv_path):
    # Lade das Bild
    image = cv2.imread(image_path)
    if image is None:
        print(f"Fehler beim Laden des Bildes: {image_path}")
        return

    # Hole die Dimensionen des Bildes
    height, width, _ = image.shape

    # Lade die CSV-Datei mit den Bounding Boxes
    if not os.path.exists(csv_path):
        print(f"CSV-Datei nicht gefunden: {csv_path}")
        return
    
    df = pd.read_csv(csv_path)
    #print(df.head())  # Ausgabe der ersten Zeilen der CSV-Datei zur Überprüfung

    # Zeichne jede Bounding Box auf das Bild
    for _, row in df.iterrows():
        try:
            # Werte aus der CSV
            x = row['x']
            y = row['y']
            box_width = row['width']
            box_height = row['height']
            iou = round(row['IoU'], 2)  # Runden des IoU-Werts auf 2 Nachkommastellen
            #print("x",x,"y",y,"box_width",box_width,"box_height",box_height,"iou",iou)

            # Berechne die Koordinaten der linken oberen Ecke und der unteren rechten Ecke
            x1 = int(x - box_width / 2)  # x1 ist die linke obere Ecke
            y1 = int(y - box_height / 2)  # y1 ist die obere linke Ecke
            x2 = int(x + box_width / 2)  # x2 ist die rechte untere Ecke
            y2 = int(y + box_height / 2)  # y2 ist die rechte untere Ecke
            #print("x1",x1,"y1",y1,"x2",x2,"y2",y2)
            # Rechteck zeichnen (x1, y1 ist die obere linke Ecke, x2, y2 ist die untere rechte Ecke)
            cv2.rectangle(image, (x1, y1), (x2, y2), (0, 0, 255), 3)  # Blaue Farbe und Dicke = 3

            # Füge den IoU-Wert als Text neben der Bounding Box hinzu
            label = f"IoU: {iou}"
            cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 2, (0, 0, 255), 3)
        except KeyError as e:
            print(f"KeyError: {e} in row {row}")

    # Konvertiere das Bild nach RGB für Matplotlib
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Zeige das Bild an
    plt.figure(figsize=(12, 8))  # Setzt eine größere Figurgröße für bessere Anzeige
    plt.imshow(image_rgb)
    plt.axis('off')  # Achsen ausschalten
    plt.show()


def process_folder(image_folder, csv_folder):
    # Liste aller Bilddateien im Ordner
    image_files = [f for f in os.listdir(image_folder) if f.endswith(('.jpg',".JPG", '.png'))]

    # Sortiere die Bilder umgekehrt, sodass das letzte Bild zuerst kommt
    image_files.sort(reverse=True)

    for image_file in image_files:
        # Vollständiger Pfad zum Bild
        image_path = os.path.join(image_folder, image_file)
        #print(image_path)
        
        # Entferne den "detected_" Präfix aus dem Bildnamen
        csv_file_name = image_file.replace("detected_", "")
        print(csv_file_name)
        
        # Erzeuge den Pfad zur zugehörigen CSV-Datei
        csv_file = f"BBM_{csv_file_name}.csv"  # Beispiel für den CSV-Dateinamen
        csv_path = os.path.join(csv_folder, csv_file)
        #print(csv_path)

        print(f"\nVerarbeite Bild: {image_file}")
        draw_bboxes_from_csv(image_path, csv_path)


#image_folder_path = r"C:\Users\felix\Documents\MT_Data\Zone14_road"
#detect_folder_path = r"C:\Users\felix\Documents\MT_Data\Yolo\zone14_road"


process_folder(image_folder_path, detect_folder_path)

# %% [markdown]
# ### Compare&Save moving Cars BBs to CSV

# %%
import os
import pandas as pd
import re

csv_results = r"C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars"
#detect_folder_path = r"C:\Users\felix\Documents\GitHub\CarDetection\testzone\z1_turn\detect"
# Sicherstellen, dass der Ergebnisordner existiert
os.makedirs(csv_results, exist_ok=True)

# Alle Dateien im Ordner holen
data = os.listdir(detect_folder_path)

# Filtere *_detections.csv und BBM_*.csv Dateien
detections_files = [f for f in data if f.endswith("_detections.csv")]
bbm_files = [f for f in data if f.startswith("BBM_") and f.endswith(".csv")]

# Erzeuge eine Zuordnung nach Bildziffern
detections_dict = {re.sub(r'_detections.csv$', '', f): f for f in detections_files}
bbm_dict = {re.sub(r'BBM_', '', f).replace('.csv', ''): f for f in bbm_files}

# Nur passende Paare verarbeiten
for id, detection_file in detections_dict.items():
    if id in bbm_dict:
        bbm_file = bbm_dict[id]

        csv1_pfad = os.path.join(detect_folder_path, detection_file)
        csv2_pfad = os.path.join(detect_folder_path, bbm_file)

        # CSV-Dateien laden
        df1 = pd.read_csv(csv1_pfad)
        df2 = pd.read_csv(csv2_pfad)

        # Relevante Spalten (nur x und y) extrahieren
        set1 = set(zip(df1["x"], df1["y"]))
        set2 = set(zip(df2["x"], df2["y"]))

        # Einträge, die nur in der ersten Datei vorkommen
        unique_entries = set1 - set2

        # Falls keine Unterschiede, nächste Datei verarbeiten
        if not unique_entries:
            print(f"Keine einzigartigen Einträge für {id}.") 
            continue
        
        # Daten für die Ausgabe filtern
        df1_filtered = df1[df1.apply(lambda row: (row["x"], row["y"]) in unique_entries, axis=1)]

        # Ergebnisdatei speichern
        ergebnis_datei = os.path.join(csv_results, f"movingcar_BB_{id}.csv")
        df1_filtered.to_csv(ergebnis_datei, index=False)
        print(f"Vergleich für {id} save {ergebnis_datei}")

print("Done!")
# Out:
# Vergleich für DJI_0613.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0613.JPG.csv
# Vergleich für DJI_0614.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0614.JPG.csv
# Vergleich für DJI_0615.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0615.JPG.csv
# Vergleich für DJI_0616.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0616.JPG.csv
# Vergleich für DJI_0617.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0617.JPG.csv
# Vergleich für DJI_0618.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0618.JPG.csv
# Vergleich für DJI_0619.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0619.JPG.csv
# Vergleich für DJI_0620.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0620.JPG.csv
# Vergleich für DJI_0621.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0621.JPG.csv
# Vergleich für DJI_0622.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0622.JPG.csv
# Vergleich für DJI_0623.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0623.JPG.csv
# Vergleich für DJI_0624.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0624.JPG.csv
# Vergleich für DJI_0625.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0625.JPG.csv
# Vergleich für DJI_0626.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0626.JPG.csv
# Vergleich für DJI_0627.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0627.JPG.csv
# Vergleich für DJI_0628.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0628.JPG.csv
# Vergleich für DJI_0629.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0629.JPG.csv
# Vergleich für DJI_0630.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0630.JPG.csv
# Vergleich für DJI_0631.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0631.JPG.csv
# Vergleich für DJI_0632.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0632.JPG.csv
# Vergleich für DJI_0633.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0633.JPG.csv
# Vergleich für DJI_0634.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0634.JPG.csv
# Vergleich für DJI_0635.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0635.JPG.csv
# Vergleich für DJI_0636.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0636.JPG.csv
# Vergleich für DJI_0637.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0637.JPG.csv
# Vergleich für DJI_0638.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0638.JPG.csv
# Keine einzigartigen Einträge für DJI_0639.JPG.
# Keine einzigartigen Einträge für DJI_0640.JPG.
# Vergleich für DJI_0641.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0641.JPG.csv
# Vergleich für DJI_0642.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0642.JPG.csv
# Keine einzigartigen Einträge für DJI_0643.JPG.
# Vergleich für DJI_0644.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0644.JPG.csv
# Vergleich für DJI_0645.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0645.JPG.csv
# Vergleich für DJI_0646.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0646.JPG.csv
# Vergleich für DJI_0647.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0647.JPG.csv
# Vergleich für DJI_0648.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0648.JPG.csv
# Keine einzigartigen Einträge für DJI_0649.JPG.
# Keine einzigartigen Einträge für DJI_0650.JPG.
# Keine einzigartigen Einträge für DJI_0651.JPG.
# Keine einzigartigen Einträge für DJI_0652.JPG.
# Vergleich für DJI_0653.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0653.JPG.csv
# Vergleich für DJI_0654.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0654.JPG.csv
# Keine einzigartigen Einträge für DJI_0655.JPG.
# Vergleich für DJI_0656.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0656.JPG.csv
# Vergleich für DJI_0657.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0657.JPG.csv
# Vergleich für DJI_0658.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0658.JPG.csv
# Vergleich für DJI_0659.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0659.JPG.csv
# Vergleich für DJI_0660.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0660.JPG.csv
# Vergleich für DJI_0661.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0661.JPG.csv
# Vergleich für DJI_0662.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0662.JPG.csv
# Vergleich für DJI_0663.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0663.JPG.csv
# Keine einzigartigen Einträge für DJI_0664.JPG.
# Keine einzigartigen Einträge für DJI_0665.JPG.
# Vergleich für DJI_0666.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0666.JPG.csv
# Vergleich für DJI_0667.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0667.JPG.csv
# Keine einzigartigen Einträge für DJI_0668.JPG.
# Keine einzigartigen Einträge für DJI_0669.JPG.
# Keine einzigartigen Einträge für DJI_0670.JPG.
# Vergleich für DJI_0671.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0671.JPG.csv
# Keine einzigartigen Einträge für DJI_0672.JPG.
# Keine einzigartigen Einträge für DJI_0673.JPG.
# Keine einzigartigen Einträge für DJI_0674.JPG.
# Keine einzigartigen Einträge für DJI_0675.JPG.
# Keine einzigartigen Einträge für DJI_0676.JPG.
# Vergleich für DJI_0677.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0677.JPG.csv
# Vergleich für DJI_0678.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0678.JPG.csv
# Keine einzigartigen Einträge für DJI_0679.JPG.
# Vergleich für DJI_0680.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0680.JPG.csv
# Vergleich für DJI_0681.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0681.JPG.csv
# Vergleich für DJI_0682.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0682.JPG.csv
# Vergleich für DJI_0683.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0683.JPG.csv
# Vergleich für DJI_0684.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0684.JPG.csv
# Vergleich für DJI_0685.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0685.JPG.csv
# Vergleich für DJI_0686.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0686.JPG.csv
# Vergleich für DJI_0687.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0687.JPG.csv
# Keine einzigartigen Einträge für DJI_0688.JPG.
# Vergleich für DJI_0689.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0689.JPG.csv
# Vergleich für DJI_0690.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0690.JPG.csv
# Vergleich für DJI_0691.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0691.JPG.csv
# Vergleich für DJI_0692.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0692.JPG.csv
# Vergleich für DJI_0693.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0693.JPG.csv
# Vergleich für DJI_0694.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0694.JPG.csv
# Vergleich für DJI_0695.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0695.JPG.csv
# Vergleich für DJI_0696.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0696.JPG.csv
# Vergleich für DJI_0697.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0697.JPG.csv
# Vergleich für DJI_0698.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0698.JPG.csv
# Vergleich für DJI_0699.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0699.JPG.csv
# Vergleich für DJI_0700.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0700.JPG.csv
# Vergleich für DJI_0701.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0701.JPG.csv
# Vergleich für DJI_0702.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0702.JPG.csv
# Vergleich für DJI_0703.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0703.JPG.csv
# Vergleich für DJI_0704.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0704.JPG.csv
# Vergleich für DJI_0705.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0705.JPG.csv
# Vergleich für DJI_0706.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0706.JPG.csv
# Vergleich für DJI_0707.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0707.JPG.csv
# Vergleich für DJI_0708.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0708.JPG.csv
# Vergleich für DJI_0709.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0709.JPG.csv
# Vergleich für DJI_0710.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0710.JPG.csv
# Vergleich für DJI_0711.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0711.JPG.csv
# Vergleich für DJI_0712.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0712.JPG.csv
# Vergleich für DJI_0713.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0713.JPG.csv
# Vergleich für DJI_0714.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0714.JPG.csv
# Vergleich für DJI_0715.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0715.JPG.csv
# Vergleich für DJI_0716.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0716.JPG.csv
# Vergleich für DJI_0717.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0717.JPG.csv
# Vergleich für DJI_0718.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0718.JPG.csv
# Vergleich für DJI_0719.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0719.JPG.csv
# Vergleich für DJI_0720.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0720.JPG.csv
# Vergleich für DJI_0721.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0721.JPG.csv
# Vergleich für DJI_0722.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0722.JPG.csv
# Vergleich für DJI_0723.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0723.JPG.csv
# Vergleich für DJI_0724.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0724.JPG.csv
# Vergleich für DJI_0725.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0725.JPG.csv
# Vergleich für DJI_0726.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0726.JPG.csv
# Vergleich für DJI_0727.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0727.JPG.csv
# Vergleich für DJI_0728.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0728.JPG.csv
# Vergleich für DJI_0729.JPG save C:\Users\felix\Documents\MT_Data\results\Z1_intersection\movingcars\movingcar_BB_DJI_0729.JPG.csv
# Done!
