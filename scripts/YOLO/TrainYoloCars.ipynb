# %%
import os
HOME = r"C:\Users\felix\Documents\My_Python\yolov9"
print(HOME)
# Define paths
data_yaml = "./yolov9/data/ownDataset1.yaml"  # Path to your data.yaml file
weights_path = r"C:\Users\felix\Documents\My_Python\weights\gelan-c.pt"  # Path to the pre-trained weights
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'
# Out:
# C:\Users\felix\Documents\My_Python\yolov9

# %%
# !python -c "import torch; print(torch.cuda.is_available())"
# Out:
# True

# %%
# !python ./yolov9/train.py \
--batch 16 --epochs 30 --img 640 --device 0 --close-mosaic 15 \
--data {data_yaml} \
--weights {weights_path} \
--cfg models/detect/gelan-c.yaml \
--hyp hyp.scratch-high.yaml
# Out:
# train: weights=C:\Users\felix\Documents\My_Python\weights\gelan-c.pt, cfg=models/detect/gelan-c.yaml, data=./yolov9/data/ownDataset1.yaml, hyp=hyp.scratch-high.yaml, epochs=30, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov9\runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=15, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLOv5  1e33dbb Python-3.12.4 torch-2.4.1 CUDA:0 (NVIDIA GeForce GTX 1080 Ti, 11264MiB)
#
# ...

# %%
# !python ./yolov9/val.py \
--img 640 --batch 16 --conf 0.01 --iou 0.7 --device 0 \
--data {data_yaml} \
--weights {HOME}/runs/train/exp28/weights/best.pt
# Out:
# val: data=./yolov9/data/ownDataset1.yaml, weights=['C:\\Users\\felix\\Documents\\My_Python\\yolov9/runs/train/exp26/weights/best.pt'], batch_size=16, imgsz=640, conf_thres=0.01, iou_thres=0.7, max_det=300, task=val, device=0, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=yolov9\runs\val, name=exp, exist_ok=False, half=False, dnn=False, min_items=0
# WARNING  confidence threshold 0.01 > 0.001 produces invalid results
# YOLOv5  1e33dbb Python-3.12.4 torch-2.4.1 CUDA:0 (NVIDIA GeForce GTX 1080 Ti, 11264MiB)
#
# ...

# %%
# !python ./yolov9/train.py -help
# Out:
# usage: train.py [-h] [--weights WEIGHTS] [--cfg CFG] [--data DATA] [--hyp HYP]
#                 [--epochs EPOCHS] [--batch-size BATCH_SIZE] [--imgsz IMGSZ]
#                 [--rect] [--resume [RESUME]] [--nosave] [--noval]
#                 [--noautoanchor] [--noplots] [--evolve [EVOLVE]]
#                 [--bucket BUCKET] [--cache [CACHE]] [--image-weights]
#                 [--device DEVICE] [--multi-scale] [--single-cls]
#                 [--optimizer {SGD,Adam,AdamW,LION}] [--sync-bn]
#                 [--workers WORKERS] [--project PROJECT] [--name NAME]
#                 [--exist-ok] [--quad] [--cos-lr] [--flat-cos-lr] [--fixed-lr]
#                 [--label-smoothing LABEL_SMOOTHING] [--patience PATIENCE]
#                 [--freeze FREEZE [FREEZE ...]] [--save-period SAVE_PERIOD]
#                 [--seed SEED] [--local_rank LOCAL_RANK]
#                 [--min-items MIN_ITEMS] [--close-mosaic CLOSE_MOSAIC]
# ...
